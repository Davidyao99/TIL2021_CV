# %% [markdown]
# <a href="https://colab.research.google.com/github/Davidyao99/TIL2021_CV/blob/master/TIL21_CV_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Downloading Dependencies

# %% [markdown]
# ## Github referenced and adapted from:
# https://github.com/anhtuan85/Data-Augmentation-for-Object-Detection (for rotation and random zoom)
# https://github.com/UjjwalSaxena/Automold--Road-Augmentation-Library.git ( for addition of rain augmentation)

# %%
# First, we need to install pycocotools. This library will be used for computing the evaluation metrics following the COCO metric for intersection over union.
# The version by default in Colab has a bug fixed in https://github.com/cocodataset/cocoapi/pull/354
# !pip install cython
# !pip install -U 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'
# Out:
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (0.29.23)
# Collecting git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI
#   Cloning https://github.com/cocodataset/cocoapi.git to /tmp/pip-req-build-6d6qdpf7
#   Running command git clone -q https://github.com/cocodataset/cocoapi.git /tmp/pip-req-build-6d6qdpf7
# Requirement already satisfied, skipping upgrade: setuptools>=18.0 in /usr/local/lib/python3.7/dist-packages (from pycocotools==2.0) (57.0.0)
# Requirement already satisfied, skipping upgrade: cython>=0.27.3 in /usr/local/lib/python3.7/dist-packages (from pycocotools==2.0) (0.29.23)
# Requirement already satisfied, skipping upgrade: matplotlib>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from pycocotools==2.0) (3.2.2)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (0.10.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (1.3.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.11 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (1.19.5)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (2.4.7)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (2.8.1)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.7/dist-packages (from cycler>=0.10->matplotlib>=2.1.0->pycocotools==2.0) (1.15.0)
# Building wheels for collected packages: pycocotools
#   Building wheel for pycocotools (setup.py) ... done
#   Created wheel for pycocotools: filename=pycocotools-2.0-cp37-cp37m-linux_x86_64.whl size=263899 sha256=39a09b9ff94a7e820e09a1749f636eba9bc37b76b906335674576c75567c9d76
#   Stored in directory: /tmp/pip-ephem-wheel-cache-q85wt16w/wheels/90/51/41/646daf401c3bc408ff10de34ec76587a9b3ebfac8d21ca5c3a
# Successfully built pycocotools
# Installing collected packages: pycocotools
#   Found existing installation: pycocotools 2.0.2
#     Uninstalling pycocotools-2.0.2:
#       Successfully uninstalled pycocotools-2.0.2
# Successfully installed pycocotools-2.0

# %%
import json
import math
import os
import random
import sys
import time

import numpy as np
import torch
import torch.utils.data
import torchvision
import matplotlib.pyplot as plt

from PIL import Image, ImageDraw
from pycocotools.coco import COCO
from pycocotools.cocoeval import COCOeval
from torchvision import transforms
from torchvision.ops import batched_nms
from torchvision.transforms import functional as F

# %%
from typing import List, Tuple

import torchvision.models as models

from torchvision.models.detection.backbone_utils import resnet_fpn_backbone
from torchvision.models.detection.faster_rcnn import FasterRCNN
from torchvision.models.detection.rpn import AnchorGenerator
from torchvision.ops import MultiScaleRoIAlign

# %% [markdown]
# In `references/detection/,` we have a number of helper functions to simplify training and evaluating detection models.
# Here, we will use `references/detection/utils.py` and `references/detection/coco_eval.py`.
#
# Let's copy those files (and their dependencies) in here so that they are available in the notebook

# %%
# %%shell
#
# Download TorchVision repo to use some files from references/detection
# git clone https://github.com/pytorch/vision.git
# cd vision
# git checkout v0.3.0
#
# cp references/detection/utils.py ../
# cp references/detection/coco_eval.py ../
# Out:
# /bin/bash: line 1: Download: command not found
# Cloning into 'vision'...
# remote: Enumerating objects: 29429, done.
# remote: Counting objects: 100% (1971/1971), done.
# remote: Compressing objects: 100% (537/537), done.
# remote: Total 29429 (delta 1458), reused 1857 (delta 1397), pack-reused 27458
# Receiving objects: 100% (29429/29429), 37.46 MiB | 35.03 MiB/s, done.
# Resolving deltas: 100% (22073/22073), done.
# Note: checking out 'v0.3.0'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by performing another checkout.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -b with the checkout command again. Example:
#
#   git checkout -b <new-branch-name>
#
# HEAD is now at be376084 version check against PyTorch's CUDA version

# %%
# !git clone https://github.com/UjjwalSaxena/Automold--Road-Augmentation-Library.git
# Out:
# fatal: destination path 'Automold--Road-Augmentation-Library' already exists and is not an empty directory.

# %%
# cd Automold--Road-Augmentation-Library
# Out:
# /content/Automold--Road-Augmentation-Library

# %%
import utils
from coco_eval import CocoEvaluator

# %%
# check if cuda GPU is available, make sure you're using GPU runtime on Google Colab
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device) # you should output "cuda"
# Out:
# cuda

# %%
# mount your google drive
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# ## Object Detection Dataset
# We will be providing the base dataset that will be used for the first task of the Object Detection competition.

# %%
# You should have uploaded the training dataset onto your google drive.
base_folder = '/content/drive/MyDrive/TIL2021CVpersonal' # Change this path to your folder for this competition
zipfile_name = 'c5ALL.zip'
training_path = os.path.join(base_folder, zipfile_name) # zip file for training dataset

# %%
# unzip the training dataset
# !apt-get install p7zip-full
!7z x $training_path
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# p7zip-full is already the newest version (16.02+dfsg-6).
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.
#
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 7532512093 bytes (7184 MiB)
#
# Extracting archive: /content/drive/MyDrive/TIL2021CVpersonal/c5ALL.zip
# 100% 26330 Open
# ERRORS:
# Headers Error
#
# --
# Path = /content/drive/MyDrive/TIL2021CVpersonal/c5ALL.zip
# Type = zip
# ERRORS:
# Headers Error
# Physical Size = 7532512093
# 64-bit = +
#
#  99% 26325 - c5ALL/images/ffea1290aa9ba6de.jpg
#
# Archives with Errors: 1
#
# Open Errors: 1

# %%
# Code below is used only for implementation rain augmentation. Code from library has to be modified to match data augmentation given by DSTA

# %%
# !git clone https://github.com/UjjwalSaxena/Automold--Road-Augmentation-Library.git

# %%
# import os
# from lib import Automold as am
# from lib import Helpers as hp
# from PIL import Image
# import random

# original_path = '/content/reducedOI_INDSTA_c3/images'
# RAINAUGMENTFRACTION = 0.3

# for filename in os.listdir(original_path):
#   if random.random() < RAINAUGMENTFRACTION:
#     name = filename.split('.')[0]

#     images= hp.load_images(os.path.join(original_path, filename))

#     rainy_images= am.add_rain(images, rain_type='torrential') 
#     im = Image.fromarray(rainy_images[0])
#     im.save(os.path.join(original_path, filename))

# %% [markdown]
# ### Defining the Dataset
#
# The [torchvision reference scripts for training object detection](https://github.com/pytorch/vision/tree/v0.3.0/references/detection) allows for easily supporting adding new custom datasets.
# The dataset should inherit from the standard `torch.utils.data.Dataset` class, and implement `__len__` and `__getitem__`.
#
# The only specificity that we require is that the dataset `__getitem__` should return:
#
# * image: a PIL Image of size (H, W)
# * target: a dict containing the following fields
#     * `boxes` (`FloatTensor[N, 4]`): the coordinates of the `N` bounding boxes in `[x0, y0, x1, y1]` format, ranging from `0` to `W` and `0` to `H`
#     * `labels` (`Int64Tensor[N]`): the label for each bounding box
#     * `image_id` (`Int64Tensor[1]`): an image identifier. It should be unique between all the images in the dataset, and is used during evaluation
#     * `area` (`Tensor[N]`): The area of the bounding box. This is used during evaluation with the COCO metric, to separate the metric scores between small, medium and large boxes.
#     * `iscrowd` (`UInt8Tensor[N]`): instances with `iscrowd=True` will be ignored during evaluation.
#
# If your model returns the above methods, they will make it work for both training and evaluation, and will use the evaluation scripts from pycocotools.
#
# Additionally, if you want to use aspect ratio grouping during training (so that each batch only contains images with similar aspect ratio), then it is recommended to also implement a `get_height_and_width` method, which returns the height and the width of the image. If this method is not provided, we query all elements of the dataset via `__getitem__` , which loads the image in memory and is slower than if a custom method is provided.
#
# Let's write a `torch.utils.data.Dataset` class for this dataset.

# %%
class TILDataset(torch.utils.data.Dataset):
    def __init__(self, root, annotation, transforms=None):
        self.root = root
        self.transforms = transforms
        self.coco = COCO(annotation)
        self.ids = list(sorted(self.coco.imgs.keys()))
        cats = self.coco.loadCats(self.coco.getCatIds())
        self.cat2name = {cat['id']:cat['name'] for cat in cats} # maps category id to category name (useful for visualization)

    def __getitem__(self, index):
        coco = self.coco
        img_id = self.ids[index] # Image ID
        ann_ids = coco.getAnnIds(imgIds=img_id) # get annotation id from coco
        coco_annotation = coco.loadAnns(ann_ids) # target coco_annotation file for an image
        path = coco.loadImgs(img_id)[0]['file_name'] # path for input image
        img = Image.open(os.path.join(self.root, 'images', path)).convert('RGB') # open the input image

        # number of objects in the image
        num_objs = len(coco_annotation)

        # Bounding boxes for objects
        # In coco format, bbox = [xmin, ymin, width, height]
        # In pytorch, the input should be [xmin, ymin, xmax, ymax]
        boxes = []
        for i in range(num_objs):
            xmin = coco_annotation[i]['bbox'][0]
            ymin = coco_annotation[i]['bbox'][1]
            xmax = xmin + coco_annotation[i]['bbox'][2]
            ymax = ymin + coco_annotation[i]['bbox'][3]
            boxes.append([xmin, ymin, xmax, ymax])
        boxes = torch.as_tensor(boxes, dtype=torch.float32)

        # Labels
        labels = []
        for i in range(num_objs):
            labels.append(coco_annotation[i]['category_id'])
        labels = torch.as_tensor(labels, dtype=torch.int64)

        # Tensorise img_id
        img_id = torch.tensor([img_id])

        # Size of bbox (Rectangular)
        areas = []
        for i in range(num_objs):
            areas.append(coco_annotation[i]['area'])
        areas = torch.as_tensor(areas, dtype=torch.float32)

        # suppose all instances are not crowd
        iscrowd = torch.zeros((num_objs,), dtype=torch.int64)

        # Annotation is in dictionary format
        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["image_id"] = img_id
        target["area"] = areas
        target["iscrowd"] = iscrowd

        if self.transforms is not None:
            img, target = self.transforms(img, target)

        return img, target

    def __len__(self):
        return len(self.ids)

# %% [markdown]
# That's all for the dataset. Let's see how the outputs are structured for this dataset

# %%
til_root = os.path.join("/content", zipfile_name.split('.')[0]) # extracted training dataset path
train_annotation = os.path.join(til_root, "train.json")
val_annotation = os.path.join(til_root, "val.json")

dataset = TILDataset(til_root, train_annotation)
dataset[30]
# Out:
# loading annotations into memory...
# Done (t=0.29s)
# creating index...
# index created!
# (<PIL.Image.Image image mode=RGB size=500x375 at 0x7F803B7EAAD0>,
#  {'area': tensor([14504.]),
#   'boxes': tensor([[157., 137., 353., 211.]]),
#   'image_id': tensor([31]),
#   'iscrowd': tensor([0]),
#   'labels': tensor([8])})

# %% [markdown]
# So we can see that by default, the dataset returns a `PIL.Image` and a dictionary containing several fields, including `boxes` and `labels`.
#
# Let's next look at one example from the training set.

# %%
source_img, img_annots = dataset[30]
draw = ImageDraw.Draw(source_img)
for i in range(len(img_annots["boxes"])):
    x1, y1, x2, y2 = img_annots["boxes"][i]
    label = int(img_annots["labels"][i])

    draw.rectangle(((x1, y1), (x2, y2)), outline="red")
    text = f'{dataset.cat2name[label]}'
    draw.text((x1+5, y1+5), text)
display(source_img)
# Out:
# <PIL.Image.Image image mode=RGB size=500x375 at 0x7F803B6C68D0>

# %% [markdown]
# ## Setting up the Model
#
# In this object detection example, we will make use of Faster R-CNN model with a ResNet50-FPN backbone. To understand the underlying code structure, you can read this [article](https://zhuanlan.zhihu.com/p/145842317) (right click and translate to English).
#
# Feel free to explore with different hyper-parameters to see what works best!

# %%
# hyper-parameters
params = {'FILE_NAME': 'minimal_rot_c5_fulldata_v1',
          'BATCH_SIZE': 16,
          'LR': 0.005,
          'CLASSES': 9,
          'MAXEPOCHS': 50,
          'BACKBONE': 'resnet50',
          'FPN': True,
          'ANCHOR_SIZE': ((32,), (64,), (128,), (256,), (512,)),
          'ASPECT_RATIOS': ((0.5, 1.0, 2.0),),
          'MIN_SIZE': 512,
          'MAX_SIZE': 512,
          'IMG_MEAN': [0.485, 0.456, 0.406],
          'IMG_STD': [0.229, 0.224, 0.225],
          'IOU_THRESHOLD': 0.5,
          'AUG_ROT_PROB': 0.1,
          'AUG_ROT_ANGLE': 10, # 10 means maximum of +-10 deg in rotation
          'AUG_GRAYSCALE_PROB': 0.05,
          'AUG_BCS_PROB': 1.0,
          'AUG_BCS_DELTA': 0.2, # (1-delta, 1+delta) 
          'AUG_HUE_PROB': 0,
          'AUG_HUE_AMT': 0.1,
          'AUG_ZOOM_PROB': 0,
          'AUG_ZOOM_SCALE': 0.8, # 0.7 will mean maximum area scaling is (0.7 * width) * (0.7 * height)
          'AUG_BLUR_PROB': 0,
          'C5_PROB': 0.5, # <-----------CHANGE HERE FOR CHALLENGE 5----------------------------
          'LR_SCHEDULER_GAMMA': 0.4,
          'LR_SCHEDULER_STEP': 4, # default values mean every 3 epochs, lr * 0.3
          'TRAINABLE_LAYERS': 4,
          }
# !mkdir {base_folder}/{params['FILE_NAME']}

param_save_path = f"{base_folder}/{params['FILE_NAME']}/params.json"
with open(param_save_path, 'w') as fp:
    json.dump(params, fp)

# %%
def get_resnet_backbone(backbone_name: str):
    """
    Returns a resnet backbone pretrained on ImageNet.
    Removes the average-pooling layer and the linear layer at the end.
    """
    if backbone_name == 'resnet18':
        pretrained_model = models.resnet18(pretrained=True, progress=False)
        out_channels = 512
    elif backbone_name == 'resnet34':
        pretrained_model = models.resnet34(pretrained=True, progress=False)
        out_channels = 512
    elif backbone_name == 'resnet50':
        pretrained_model = models.resnet50(pretrained=True, progress=False)
        out_channels = 2048
    elif backbone_name == 'resnet101':
        pretrained_model = models.resnet101(pretrained=True, progress=False)
        out_channels = 2048
    elif backbone_name == 'resnet152':
        pretrained_model = models.resnet152(pretrained=True, progress=False)
        out_channels = 2048

    backbone = torch.nn.Sequential(*list(pretrained_model.children())[:-2])
    backbone.out_channels = out_channels

    return backbone

# %%
def get_resnet_fpn_backbone(backbone_name: str):
    """
    Returns a specified ResNet backbone with FPN pretrained on ImageNet.
    """
    return resnet_fpn_backbone(backbone_name, pretrained=True, trainable_layers=params['TRAINABLE_LAYERS'])

# %%
def get_anchor_generator(anchor_size: Tuple[tuple] = None, aspect_ratios: Tuple[tuple] = None):
    """Returns the anchor generator."""
    if anchor_size is None:
        anchor_size = ((16,), (32,), (64,), (128,))
    if aspect_ratios is None:
        aspect_ratios = ((0.5, 1.0, 2.0),) * len(anchor_size)

    anchor_generator = AnchorGenerator(sizes=anchor_size,
                                       aspect_ratios=aspect_ratios)
    return anchor_generator

# %%
def get_roi_pool(featmap_names: List[str] = None, output_size: int = 7, sampling_ratio: int = 2):
    """Returns the ROI Pooling"""
    if featmap_names is None:
        # default for resnet with FPN
        featmap_names = ['0', '1', '2', '3']

    roi_pooler = MultiScaleRoIAlign(featmap_names=featmap_names,
                                    output_size=output_size,
                                    sampling_ratio=sampling_ratio)

    return roi_pooler

# %%
def get_fasterRCNN(backbone: torch.nn.Module,
                   anchor_generator: AnchorGenerator,
                   roi_pooler: MultiScaleRoIAlign,
                   num_classes: int,
                   image_mean: List[float] = [0.485, 0.456, 0.406],
                   image_std: List[float] = [0.229, 0.224, 0.225],
                   min_size: int = 512,
                   max_size: int = 1024,
                   **kwargs
                   ):
    """Returns the Faster-RCNN model. Default normalization: ImageNet"""
    model = FasterRCNN(backbone=backbone,
                       rpn_anchor_generator=anchor_generator,
                       box_roi_pool=roi_pooler,
                       num_classes=num_classes,
                       image_mean=image_mean,  # ImageNet
                       image_std=image_std,  # ImageNet
                       min_size=min_size,
                       max_size=max_size,
                       **kwargs
                       )
    model.num_classes = num_classes
    model.image_mean = image_mean
    model.image_std = image_std
    model.min_size = min_size
    model.max_size = max_size

    return model

# %%
def get_fasterRCNN_resnet(num_classes: int,
                          backbone_name: str,
                          anchor_size: List[float],
                          aspect_ratios: List[float],
                          fpn: bool = True,
                          min_size: int = 512,
                          max_size: int = 1024,
                          **kwargs
                          ):
    """Returns the Faster-RCNN model with resnet backbone with and without fpn."""

    # Backbone
    if fpn:
        backbone = get_resnet_fpn_backbone(backbone_name=backbone_name)
    else:
        backbone = get_resnet_backbone(backbone_name=backbone_name)

    # Anchors
    anchor_size = anchor_size
    aspect_ratios = aspect_ratios * len(anchor_size)
    anchor_generator = get_anchor_generator(anchor_size=anchor_size, aspect_ratios=aspect_ratios)

    # ROI Pool
    with torch.no_grad():
        backbone.eval()
        random_input = torch.rand(size=(1, 3, 512, 512))
        features = backbone(random_input)

    if isinstance(features, torch.Tensor):
        from collections import OrderedDict

        features = OrderedDict([('0', features)])

    featmap_names = [key for key in features.keys() if key.isnumeric()]

    roi_pool = get_roi_pool(featmap_names=featmap_names)

    # Model
    return get_fasterRCNN(backbone=backbone,
                          anchor_generator=anchor_generator,
                          roi_pooler=roi_pool,
                          num_classes=num_classes,
                          min_size=min_size,
                          max_size=max_size,
                          **kwargs)

# %%
model = get_fasterRCNN_resnet(num_classes=params['CLASSES'],
                              backbone_name=params['BACKBONE'],
                              anchor_size=params['ANCHOR_SIZE'],
                              aspect_ratios=params['ASPECT_RATIOS'],
                              fpn=params['FPN'],
                              min_size=params['MIN_SIZE'],
                              max_size=params['MAX_SIZE'],
                              image_mean=params['IMG_MEAN'],
                              image_std=params['IMG_STD'])
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# HBox(children=(FloatProgress(value=0.0, max=102530333.0), HTML(value='')))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)

# %%
# load pretrained weights for FasterRCNN ResNet50 FPN
pretrained_dict = torch.hub.load_state_dict_from_url('https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth', progress=True)
model_dict = model.state_dict()

# filter out roi_heads.box_predictor weights
pretrained_dict = {k: v for k, v in pretrained_dict.items() if not k.startswith('roi_heads.box_predictor')}
# overwrite entries in the existing state dict
model_dict.update(pretrained_dict)
# load the new state dict
model.load_state_dict(model_dict)
# Out:
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth
# HBox(children=(FloatProgress(value=0.0, max=167502836.0), HTML(value='')))
# <All keys matched successfully>

# %%
# move model to the right device
model.to(device)
# Out:
# FasterRCNN(
#   (transform): GeneralizedRCNNTransform(
#       Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#       Resize(min_size=(512,), max_size=512, mode='bilinear')
#   )
#   (backbone): BackboneWithFPN(
#     (body): IntermediateLayerGetter(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(256, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(512, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(1024, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(2048, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (fpn): FeaturePyramidNetwork(
#       (inner_blocks): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#         (3): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (layer_blocks): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (extra_blocks): LastLevelMaxPool()
#     )
#   )
#   (rpn): RegionProposalNetwork(
#     (anchor_generator): AnchorGenerator()
#     (head): RPNHead(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (cls_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (bbox_pred): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (roi_heads): RoIHeads(
#     (box_roi_pool): MultiScaleRoIAlign(featmap_names=['0', '1', '2', '3'], output_size=(7, 7), sampling_ratio=2)
#     (box_head): TwoMLPHead(
#       (fc6): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc7): Linear(in_features=1024, out_features=1024, bias=True)
#     )
#     (box_predictor): FastRCNNPredictor(
#       (cls_score): Linear(in_features=1024, out_features=9, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=36, bias=True)
#     )
#   )
# )

# %%
# construct an optimizer
model_params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(model_params, 
                            lr=params['LR'],
                            momentum=0.9, 
                            weight_decay=0.0005)

# and a learning rate scheduler which decreases the learning rate by 10x every 3 epochs
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                               step_size=params['LR_SCHEDULER_STEP'],
                                               gamma=params['LR_SCHEDULER_GAMMA'])

# %% [markdown]
# ## Data Augmentation
#
# Let's write some helper functions for data augmentation / transformation.
#
# Do not just stop here, add in your own data augmentations! Remember to also augment the bounding boxes accordingly.

# %%
class Compose(object):
    def __init__(self, transforms):
        self.transforms = transforms

    def __call__(self, image, target):
        for t in self.transforms:
            image, target = t(image, target)
        return image, target

# %%
def rotate(image, boxes, angle):
    '''
        Rotate image and bounding box
        image: A Pil image (w, h)
        boxes: A tensors of dimensions (#objects, 4)
        
        Out: rotated image (w, h), rotated boxes
    '''
    new_image = image.copy()
    new_boxes = boxes.clone()
    num_boxes = len(boxes)
    
    #Rotate image, expand = True
    w = image.width
    h = image.height
    cx = w/2
    cy = h/2
    new_image = new_image.rotate(angle, expand= True)
    angle = np.radians(angle)
    alpha = np.cos(angle)
    beta = np.sin(angle)
    #Get affine matrix
    AffineMatrix = torch.tensor([[alpha, beta, (1-alpha)*cx - beta*cy],
                                 [-beta, alpha, beta*cx + (1-alpha)*cy]])
    
    #Rotation boxes
    box_width = (boxes[:,2] - boxes[:,0]).reshape(-1,1)
    box_height = (boxes[:,3] - boxes[:,1]).reshape(-1,1)
    
    #Get corners for boxes
    x1 = boxes[:,0].reshape(-1,1)
    y1 = boxes[:,1].reshape(-1,1)
    
    x2 = x1 + box_width
    y2 = y1 
    
    x3 = x1
    y3 = y1 + box_height
    
    x4 = boxes[:,2].reshape(-1,1)
    y4 = boxes[:,3].reshape(-1,1)
    
    corners = torch.stack((x1,y1,x2,y2,x3,y3,x4,y4), dim= 1)
    corners.reshape(num_boxes, 8)    #Tensors of dimensions (#objects, 8)
    corners = corners.reshape(-1,2) #Tensors of dimension (4* #objects, 2)
    corners = torch.cat((corners, torch.ones(corners.shape[0], 1)), dim= 1) #(Tensors of dimension (4* #objects, 3))
    corners = corners.double()
    
    cos = np.abs(AffineMatrix[0, 0])
    sin = np.abs(AffineMatrix[0, 1])
    
    nW = int((h * sin) + (w * cos))
    nH = int((h * cos) + (w * sin))
    AffineMatrix[0, 2] += (nW / 2) - cx
    AffineMatrix[1, 2] += (nH / 2) - cy
    
    #Apply affine transform
    rotate_corners = torch.mm(AffineMatrix, corners.t()).t()
    rotate_corners = rotate_corners.reshape(-1,8)
    
    x_corners = rotate_corners[:,[0,2,4,6]]
    y_corners = rotate_corners[:,[1,3,5,7]]
    
    #Get (x_min, y_min, x_max, y_max)
    x_min, _ = torch.min(x_corners, dim= 1)
    x_min = x_min.reshape(-1, 1)
    y_min, _ = torch.min(y_corners, dim= 1)
    y_min = y_min.reshape(-1, 1)
    x_max, _ = torch.max(x_corners, dim= 1)
    x_max = x_max.reshape(-1, 1)
    y_max, _ = torch.max(y_corners, dim= 1)
    y_max = y_max.reshape(-1, 1)
    
    new_boxes = torch.cat((x_min, y_min, x_max, y_max), dim= 1)
    
    scale_x = new_image.width / w
    scale_y = new_image.height / h
    
    #Resize new image to (w, h)
    new_image = new_image.resize((w, h))
    
    #Resize boxes
    new_boxes /= torch.Tensor([scale_x, scale_y, scale_x, scale_y])
    new_boxes[:, 0] = torch.clamp(new_boxes[:, 0], 0, w)
    new_boxes[:, 1] = torch.clamp(new_boxes[:, 1], 0, h)
    new_boxes[:, 2] = torch.clamp(new_boxes[:, 2], 0, w)
    new_boxes[:, 3] = torch.clamp(new_boxes[:, 3], 0, h)
    return new_image, new_boxes.to(dtype=torch.float32)

# %%
def zoom_out(image, boxes):
    '''
        Zoom out image (max scale = 2)
        image: A PIL image
        boxes: bounding boxes, a tensor of dimensions (#objects, 4)
        
        Out: new_image, new_boxes
    '''
    original_h = image.height
    original_w = image.width
    max_scale = params['AUG_ZOOM_SCALE']
    scale = random.uniform(max_scale, 1.0)
    new_h = int(scale*original_h)
    new_w = int(scale*original_w)

    image = image.resize((new_w, new_h))

    if type(image) == Image.Image:
        image = F.to_tensor(image)

    # #Resize boxes
    new_boxes = boxes * torch.Tensor([scale, scale, scale, scale])
    new_boxes[:, 0] = torch.clamp(new_boxes[:, 0], 0, new_w)
    new_boxes[:, 1] = torch.clamp(new_boxes[:, 1], 0, new_h)
    new_boxes[:, 2] = torch.clamp(new_boxes[:, 2], 0, new_w)
    new_boxes[:, 3] = torch.clamp(new_boxes[:, 3], 0, new_h)
    
    #Create an image with the filler
    filler = [0.485, 0.456, 0.406]
    filler = torch.FloatTensor(filler) #(3)
    new_image = torch.ones((3, original_h, original_w), dtype= torch.float) * filler.unsqueeze(1).unsqueeze(1)
    

    left = random.randint(0, original_w - new_w)
    right = left + new_w
    top = random.randint(0, original_h - new_h)
    bottom = top + new_h
    
    new_image[:, top:bottom, left:right] = image
    
    #Adjust bounding box
    new_boxes = new_boxes + torch.FloatTensor([left, top, left, top]).unsqueeze(0)

    return new_image, new_boxes

# %%
def generate_random_lines(imshape,slant,drop_length):    
    drops=[]
    for i in range(1500): ## If You want heavy rain, try increasing this        
      if slant<0:            
        x= np.random.randint(slant,imshape[1])        
      else:            
        x= np.random.randint(0,imshape[1]-slant)        
      y= np.random.randint(0,imshape[0]-drop_length)        
      drops.append((x,y))    
    return drops            
    
def add_rain(image):        
  imshape = image.shape    
  slant_extreme=10    
  slant= np.random.randint(-slant_extreme,slant_extreme)     
  drop_length=20    
  drop_width=2    
  drop_color=(200,200,200) ## a shade of gray    
  rain_drops= generate_random_lines(imshape,slant,drop_length)        
  for rain_drop in rain_drops:        
    cv2.line(image,(rain_drop[0],rain_drop[1]),(rain_drop[0]+slant,rain_drop[1]+drop_length),drop_color,drop_width)    
    image= cv2.blur(image,(7,7)) ## rainy view are blurry        
    brightness_coefficient = 0.7 ## rainy days are usually shady     
    image_HLS = cv2.cvtColor(image,cv2.COLOR_RGB2HLS) ## Conversion to HLS    
    image_HLS[:,:,1] = image_HLS[:,:,1]*brightness_coefficient ## scale pixel values down for channel 1(Lightness)    
    image_RGB = cv2.cvtColor(image_HLS,cv2.COLOR_HLS2RGB) ## Conversion to RGB    
  return image_RGB

# %%
# converts the image, a PIL image, into a PyTorch Tensor
class ToTensor(object):
    def __call__(self, image, target):
        if type(image) == Image.Image:
          image = F.to_tensor(image)
        return image, target

# %%
# randomly horizontal flip the images and ground-truth labels
class RandomHorizontalFlip(object):
    def __init__(self, prob):
        self.prob = prob

    def __call__(self, image, target):
        if random.random() < self.prob:
            height, width = image.shape[-2:]
            image = image.flip(-1)
            bbox = target["boxes"]
            bbox[:, [0, 2]] = width - bbox[:, [2, 0]]
            target["boxes"] = bbox
        return image, target

# %%
class Zoom(object):
    def __init__(self, prob):
        self.prob = prob

    def __call__(self, image, target):
        if not (image.width < 500 or image.height < 500):
          if random.random() < self.prob:
              image, box = zoom_out(image, target['boxes'])
              target['boxes'] = box
        return image, target

# %%
class AdjustBCS(object):
    def __init__(self, prob):
        self.prob = prob

    def __call__(self, image, target):
        delta = params['AUG_BCS_DELTA']
        amt = random.uniform(1-delta, 1+delta)
        if random.random() < self.prob:
          image = F.adjust_brightness(image, amt)
        if random.random() < self.prob:
          image = F.adjust_saturation(image, amt)
        if random.random() < self.prob:
          image = F.adjust_contrast(image, amt)
        return image, target

# %%
class AdjustHue(object):
    def __init__(self, prob):
        self.prob = prob

    def __call__(self, image, target):
        if random.random() < self.prob:
            image = F.adjust_hue(image, params['AUG_HUE_AMT'])
        return image, target

# %%
class Rotate(object):
    def __init__(self, prob):
        self.prob = prob

    def __call__(self, image, target):
        if random.random() < self.prob:
          angle = params['AUG_ROT_ANGLE']
          rot = random.uniform(-angle, angle)
          image, boxes = rotate(image, target["boxes"], rot)
          target['boxes'] = boxes  
        return image, target

# %%
class GrayScale(object):
    def __init__(self, prob):
      self.prob= prob
    def __call__(self, image, target):
      if random.random() < self.prob:
        image = F.rgb_to_grayscale(image,num_output_channels = 3)
      return image, target

# %%
class Blur(object):

    def __init__(self, prob):
      self.prob = prob

    def __call__(self, image, target):
      image = F.gaussian_blur(image, kernel_size=3) # larger the kernel, larger the blur
      return image, target

# %%
# class Posterize(object):

#     def __init__(self, prob):
#       self.prob = prob

#     def __call__(self, image, target):
#       image = F.posterize(image, bits=2)
#       return image, target

# %%
class C3(object):

    def __init__(self, prob):
      self.prob = prob

    def __call__(self, image, target):
      if random.random() < self.prob:
        width, height = image.size
        image = image.resize((width//4, height//4), Image.NEAREST)
        image = image.resize((width, height), Image.NEAREST)
        image = F.posterize(image, bits=3)
      return image, target

# %%
def get_transform(train):
    if train:
        transforms = Compose([
            AdjustBCS(params['AUG_BCS_PROB']),
            Rotate(params['AUG_ROT_PROB']),
            Blur(params['AUG_BLUR_PROB']),
            GrayScale(params['AUG_GRAYSCALE_PROB']),
            AdjustHue(params['AUG_HUE_PROB']),
            Zoom(params['AUG_ZOOM_PROB']),
            C3(params['C5_PROB']),   
            ToTensor(),
            RandomHorizontalFlip(0.5)
        ])
    else: # during evaluation, no augmentations will be done
        transforms = Compose([
            ToTensor()
        ])
    
    return transforms

# %% [markdown]
# Note that we do not need to add a mean/std normalization nor image rescaling in the data transforms, as those are handled by the R-CNN model.

# %% [markdown]
# ## Data Loaders
#
# Let's now set up our data loaders so that we can streamline the batch loading of data for our model training later on.
#
# We now have the dataset class, the models and the data transforms. Let's instantiate them

# %%
NUM_WORKERS = 4

# use our dataset and defined transformations
train_dataset = TILDataset(til_root, train_annotation, get_transform(train=True))
val_dataset = TILDataset(til_root, val_annotation, get_transform(train=False))

# define training and validation data loaders
train_loader = torch.utils.data.DataLoader(
    train_dataset, batch_size=params['BATCH_SIZE'], shuffle=True, num_workers=NUM_WORKERS,
    collate_fn=utils.collate_fn)

val_loader = torch.utils.data.DataLoader(
    val_dataset, batch_size=1, shuffle=False, num_workers=NUM_WORKERS,
    collate_fn=utils.collate_fn)
# Out:
# loading annotations into memory...
# Done (t=0.37s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
it = iter(train_loader)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
test_images, test_labels = next(it)
sample_img = test_images[0] 
img_annots = test_labels[0]
sample_img.swapaxes(0,2)
source_img = transforms.ToPILImage()(sample_img)

draw = ImageDraw.Draw(source_img)
for i in range(len(img_annots["boxes"])):
    x1, y1, x2, y2 = img_annots["boxes"][i]
    label = int(img_annots["labels"][i])

    draw.rectangle(((x1, y1), (x2, y2)), outline="red")
    text = f'{dataset.cat2name[label]}'
    draw.text((x1+5, y1+5), text)
display(source_img)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x1024 at 0x7F7FCB2B06D0>

# %% [markdown]
# ## Model Training
#
# And now let's train the model, evaluating at the end of every epoch.

# %%
def train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq):
    model.train()
    metric_logger = utils.MetricLogger(delimiter="  ")
    metric_logger.add_meter('lr', utils.SmoothedValue(window_size=1, fmt='{value:.6f}'))
    header = 'Epoch: [{}]'.format(epoch)

    lr_scheduler = None
    total_loss = 0
    counter = 0
    if epoch == 0:
        warmup_factor = 1. / 1000
        warmup_iters = min(1000, len(data_loader) - 1)

        lr_scheduler = utils.warmup_lr_scheduler(optimizer, warmup_iters, warmup_factor)

    for images, targets in metric_logger.log_every(data_loader, print_freq, header):
        images = list(image.to(device) for image in images)
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

        loss_dict = model(images, targets)
        losses = sum(loss for loss in loss_dict.values())
        loss_value = losses.item()

        if not math.isfinite(loss_value):
            print("Loss is {}, stopping training".format(loss_value))
            print(loss_dict)
            sys.exit(1)

        optimizer.zero_grad()
        losses.backward()
        optimizer.step()


        if lr_scheduler is not None:
            lr_scheduler.step()

        metric_logger.update(loss=losses, **loss_dict)
        metric_logger.update(lr=optimizer.param_groups[0]["lr"])
        total_loss += losses
        counter += 1
    total_loss /= counter
    return total_loss

# %%
@torch.no_grad()
def evaluate(model, data_loader, device):
    n_threads = torch.get_num_threads()
    torch.set_num_threads(1)
    model.eval()
    metric_logger = utils.MetricLogger(delimiter="  ")
    header = 'Test:'

    coco = data_loader.dataset.coco
    iou_types = ["bbox"]
    coco_evaluator = CocoEvaluator(coco, iou_types)

    for image, targets in metric_logger.log_every(data_loader, 100, header):
        image = list(img.to(device) for img in image)
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

        torch.cuda.synchronize()
        model_time = time.time()
        outputs = model(image)

        outputs = [{k: v for k, v in t.items()} for t in outputs]
        model_time = time.time() - model_time

        res = {target["image_id"].item(): output for target, output in zip(targets, outputs)}
        evaluator_time = time.time()
        coco_evaluator.update(res)
        evaluator_time = time.time() - evaluator_time
        metric_logger.update(model_time=model_time, evaluator_time=evaluator_time)

    # gather the stats from all processes
    metric_logger.synchronize_between_processes()
    print("Averaged stats:", metric_logger)
    coco_evaluator.synchronize_between_processes()

    # accumulate predictions from all images
    coco_evaluator.accumulate()
    coco_evaluator.summarize()
    torch.set_num_threads(n_threads)
    return coco_evaluator

# %%
loss_graph=[]
for epoch in range(params['MAXEPOCHS']):
 
    # train for one epoch, printing every 10 iterations
    loss = train_one_epoch(model, optimizer, train_loader, device, epoch, print_freq=10)

    # update the learning rate
    lr_scheduler.step()

    # evaluate on the test dataset
    evaluate(model, val_loader, device=device)
    loss_graph.append(loss)
    # save model weights
    save_path = f"{base_folder}/{params['FILE_NAME']}/model_{epoch}.ptf"
    torch.save(model.state_dict(), save_path)
print(len(loss_graph))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: [0]  [   0/1596]  eta: 5:27:11  lr: 0.000010  loss: 2.4308 (2.4308)  loss_classifier: 2.1501 (2.1501)  loss_box_reg: 0.1835 (0.1835)  loss_objectness: 0.0914 (0.0914)  loss_rpn_box_reg: 0.0058 (0.0058)  time: 12.3002  data: 10.1450  max mem: 5835
# Epoch: [0]  [  10/1596]  eta: 1:15:07  lr: 0.000060  loss: 2.3694 (2.2887)  loss_classifier: 2.1281 (2.0651)  loss_box_reg: 0.1835 (0.1821)  loss_objectness: 0.0310 (0.0372)  loss_rpn_box_reg: 0.0043 (0.0044)  time: 2.8418  data: 1.0641  max mem: 6111
# Epoch: [0]  [  20/1596]  eta: 1:00:55  lr: 0.000110  loss: 1.8753 (1.8663)  loss_classifier: 1.6184 (1.6019)  loss_box_reg: 0.2006 (0.2020)  loss_objectness: 0.0380 (0.0559)  loss_rpn_box_reg: 0.0043 (0.0064)  time: 1.8202  data: 0.1372  max mem: 6116
# Epoch: [0]  [  30/1596]  eta: 0:55:19  lr: 0.000160  loss: 0.8342 (1.4679)  loss_classifier: 0.4387 (1.1884)  loss_box_reg: 0.2199 (0.2072)  loss_objectness: 0.0420 (0.0634)  loss_rpn_box_reg: 0.0057 (0.0088)  time: 1.7230  data: 0.1185  max mem: 6116
# Epoch: [0]  [  40/1596]  eta: 0:52:41  lr: 0.000210  loss: 0.5514 (1.2295)  loss_classifier: 0.2670 (0.9589)  loss_box_reg: 0.2107 (0.2044)  loss_objectness: 0.0335 (0.0578)  loss_rpn_box_reg: 0.0058 (0.0084)  time: 1.7294  data: 0.1052  max mem: 6116
# Epoch: [0]  [  50/1596]  eta: 0:51:09  lr: 0.000260  loss: 0.5117 (1.1080)  loss_classifier: 0.2484 (0.8277)  loss_box_reg: 0.2116 (0.2091)  loss_objectness: 0.0211 (0.0624)  loss_rpn_box_reg: 0.0036 (0.0089)  time: 1.7764  data: 0.0927  max mem: 6116
# Epoch: [0]  [  60/1596]  eta: 0:50:16  lr: 0.000310  loss: 0.4947 (1.0074)  loss_classifier: 0.2452 (0.7305)  loss_box_reg: 0.2129 (0.2092)  loss_objectness: 0.0211 (0.0580)  loss_rpn_box_reg: 0.0042 (0.0096)  time: 1.8259  data: 0.0924  max mem: 6116
# Epoch: [0]  [  70/1596]  eta: 0:49:37  lr: 0.000360  loss: 0.4799 (0.9329)  loss_classifier: 0.2357 (0.6598)  loss_box_reg: 0.2141 (0.2108)  loss_objectness: 0.0199 (0.0532)  loss_rpn_box_reg: 0.0050 (0.0091)  time: 1.8644  data: 0.0895  max mem: 6116
# Epoch: [0]  [  80/1596]  eta: 0:48:52  lr: 0.000410  loss: 0.4658 (0.8743)  loss_classifier: 0.2181 (0.6049)  loss_box_reg: 0.2074 (0.2094)  loss_objectness: 0.0204 (0.0505)  loss_rpn_box_reg: 0.0045 (0.0095)  time: 1.8433  data: 0.0902  max mem: 6116
# Epoch: [0]  [  90/1596]  eta: 0:48:06  lr: 0.000460  loss: 0.4623 (0.8308)  loss_classifier: 0.2181 (0.5631)  loss_box_reg: 0.2032 (0.2113)  loss_objectness: 0.0196 (0.0474)  loss_rpn_box_reg: 0.0038 (0.0090)  time: 1.7949  data: 0.0849  max mem: 6116
# Epoch: [0]  [ 100/1596]  eta: 0:47:34  lr: 0.000509  loss: 0.4623 (0.7966)  loss_classifier: 0.2000 (0.5277)  loss_box_reg: 0.2161 (0.2106)  loss_objectness: 0.0212 (0.0489)  loss_rpn_box_reg: 0.0045 (0.0094)  time: 1.8008  data: 0.0832  max mem: 6116
# Epoch: [0]  [ 110/1596]  eta: 0:47:03  lr: 0.000559  loss: 0.4343 (0.7642)  loss_classifier: 0.1960 (0.4983)  loss_box_reg: 0.1989 (0.2105)  loss_objectness: 0.0216 (0.0464)  loss_rpn_box_reg: 0.0045 (0.0090)  time: 1.8243  data: 0.0873  max mem: 6116
# Epoch: [0]  [ 120/1596]  eta: 0:46:29  lr: 0.000609  loss: 0.4285 (0.7376)  loss_classifier: 0.1960 (0.4733)  loss_box_reg: 0.2046 (0.2098)  loss_objectness: 0.0216 (0.0454)  loss_rpn_box_reg: 0.0047 (0.0091)  time: 1.7992  data: 0.0851  max mem: 6116
# Epoch: [0]  [ 130/1596]  eta: 0:46:04  lr: 0.000659  loss: 0.4177 (0.7133)  loss_classifier: 0.1801 (0.4513)  loss_box_reg: 0.1943 (0.2092)  loss_objectness: 0.0193 (0.0439)  loss_rpn_box_reg: 0.0048 (0.0088)  time: 1.8042  data: 0.0921  max mem: 6116
# Epoch: [0]  [ 140/1596]  eta: 0:45:38  lr: 0.000709  loss: 0.4198 (0.6936)  loss_classifier: 0.1826 (0.4325)  loss_box_reg: 0.2037 (0.2092)  loss_objectness: 0.0193 (0.0431)  loss_rpn_box_reg: 0.0049 (0.0087)  time: 1.8247  data: 0.0956  max mem: 6116
# Epoch: [0]  [ 150/1596]  eta: 0:45:11  lr: 0.000759  loss: 0.4231 (0.6737)  loss_classifier: 0.1826 (0.4154)  loss_box_reg: 0.1991 (0.2079)  loss_objectness: 0.0195 (0.0417)  loss_rpn_box_reg: 0.0059 (0.0087)  time: 1.8071  data: 0.0887  max mem: 6116
# Epoch: [0]  [ 160/1596]  eta: 0:44:47  lr: 0.000809  loss: 0.4537 (0.6607)  loss_classifier: 0.1919 (0.4020)  loss_box_reg: 0.2055 (0.2093)  loss_objectness: 0.0225 (0.0408)  loss_rpn_box_reg: 0.0053 (0.0086)  time: 1.8047  data: 0.0927  max mem: 6116
# Epoch: [0]  [ 170/1596]  eta: 0:44:25  lr: 0.000859  loss: 0.4773 (0.6466)  loss_classifier: 0.1896 (0.3891)  loss_box_reg: 0.2205 (0.2093)  loss_objectness: 0.0211 (0.0398)  loss_rpn_box_reg: 0.0053 (0.0085)  time: 1.8221  data: 0.0975  max mem: 6116
# Epoch: [0]  [ 180/1596]  eta: 0:44:11  lr: 0.000909  loss: 0.3561 (0.6332)  loss_classifier: 0.1589 (0.3770)  loss_box_reg: 0.1793 (0.2083)  loss_objectness: 0.0202 (0.0393)  loss_rpn_box_reg: 0.0041 (0.0086)  time: 1.8854  data: 0.1056  max mem: 6121
# Epoch: [0]  [ 190/1596]  eta: 0:43:50  lr: 0.000959  loss: 0.3706 (0.6203)  loss_classifier: 0.1599 (0.3659)  loss_box_reg: 0.1900 (0.2081)  loss_objectness: 0.0139 (0.0380)  loss_rpn_box_reg: 0.0034 (0.0083)  time: 1.8884  data: 0.1047  max mem: 6208
# Epoch: [0]  [ 200/1596]  eta: 0:43:29  lr: 0.001009  loss: 0.3706 (0.6077)  loss_classifier: 0.1588 (0.3557)  loss_box_reg: 0.1915 (0.2072)  loss_objectness: 0.0118 (0.0367)  loss_rpn_box_reg: 0.0033 (0.0081)  time: 1.8386  data: 0.0995  max mem: 6208
# Epoch: [0]  [ 210/1596]  eta: 0:43:10  lr: 0.001059  loss: 0.3528 (0.5976)  loss_classifier: 0.1513 (0.3470)  loss_box_reg: 0.1913 (0.2066)  loss_objectness: 0.0138 (0.0359)  loss_rpn_box_reg: 0.0041 (0.0080)  time: 1.8470  data: 0.1010  max mem: 6208
# Epoch: [0]  [ 220/1596]  eta: 0:42:49  lr: 0.001109  loss: 0.3935 (0.5891)  loss_classifier: 0.1673 (0.3394)  loss_box_reg: 0.1989 (0.2068)  loss_objectness: 0.0164 (0.0351)  loss_rpn_box_reg: 0.0044 (0.0079)  time: 1.8459  data: 0.0933  max mem: 6208
# Epoch: [0]  [ 230/1596]  eta: 0:42:28  lr: 0.001159  loss: 0.3935 (0.5807)  loss_classifier: 0.1645 (0.3317)  loss_box_reg: 0.1989 (0.2064)  loss_objectness: 0.0172 (0.0347)  loss_rpn_box_reg: 0.0053 (0.0079)  time: 1.8350  data: 0.0995  max mem: 6208
# Epoch: [0]  [ 240/1596]  eta: 0:42:08  lr: 0.001209  loss: 0.3605 (0.5736)  loss_classifier: 0.1496 (0.3248)  loss_box_reg: 0.1775 (0.2063)  loss_objectness: 0.0186 (0.0346)  loss_rpn_box_reg: 0.0043 (0.0080)  time: 1.8328  data: 0.1005  max mem: 6208
# Epoch: [0]  [ 250/1596]  eta: 0:41:48  lr: 0.001259  loss: 0.3451 (0.5648)  loss_classifier: 0.1468 (0.3178)  loss_box_reg: 0.1787 (0.2053)  loss_objectness: 0.0156 (0.0338)  loss_rpn_box_reg: 0.0039 (0.0078)  time: 1.8402  data: 0.0935  max mem: 6208
# Epoch: [0]  [ 260/1596]  eta: 0:41:30  lr: 0.001309  loss: 0.3433 (0.5568)  loss_classifier: 0.1469 (0.3113)  loss_box_reg: 0.1799 (0.2043)  loss_objectness: 0.0153 (0.0334)  loss_rpn_box_reg: 0.0040 (0.0078)  time: 1.8619  data: 0.0982  max mem: 6208
# Epoch: [0]  [ 270/1596]  eta: 0:41:10  lr: 0.001359  loss: 0.3339 (0.5509)  loss_classifier: 0.1467 (0.3059)  loss_box_reg: 0.1799 (0.2035)  loss_objectness: 0.0195 (0.0334)  loss_rpn_box_reg: 0.0052 (0.0081)  time: 1.8535  data: 0.1036  max mem: 6208
# Epoch: [0]  [ 280/1596]  eta: 0:40:51  lr: 0.001409  loss: 0.3304 (0.5436)  loss_classifier: 0.1368 (0.3001)  loss_box_reg: 0.1680 (0.2025)  loss_objectness: 0.0210 (0.0330)  loss_rpn_box_reg: 0.0041 (0.0080)  time: 1.8452  data: 0.1056  max mem: 6208
# Epoch: [0]  [ 290/1596]  eta: 0:40:31  lr: 0.001459  loss: 0.3264 (0.5369)  loss_classifier: 0.1308 (0.2948)  loss_box_reg: 0.1668 (0.2017)  loss_objectness: 0.0193 (0.0326)  loss_rpn_box_reg: 0.0037 (0.0079)  time: 1.8469  data: 0.1161  max mem: 6208
# Epoch: [0]  [ 300/1596]  eta: 0:40:11  lr: 0.001508  loss: 0.3116 (0.5292)  loss_classifier: 0.1204 (0.2890)  loss_box_reg: 0.1636 (0.2004)  loss_objectness: 0.0140 (0.0320)  loss_rpn_box_reg: 0.0041 (0.0078)  time: 1.8325  data: 0.1166  max mem: 6208
# Epoch: [0]  [ 310/1596]  eta: 0:39:50  lr: 0.001558  loss: 0.3116 (0.5229)  loss_classifier: 0.1222 (0.2841)  loss_box_reg: 0.1670 (0.1994)  loss_objectness: 0.0144 (0.0317)  loss_rpn_box_reg: 0.0043 (0.0078)  time: 1.8153  data: 0.0977  max mem: 6208
# Epoch: [0]  [ 320/1596]  eta: 0:39:31  lr: 0.001608  loss: 0.2974 (0.5165)  loss_classifier: 0.1153 (0.2792)  loss_box_reg: 0.1658 (0.1983)  loss_objectness: 0.0162 (0.0313)  loss_rpn_box_reg: 0.0053 (0.0078)  time: 1.8253  data: 0.0924  max mem: 6208
# Epoch: [0]  [ 330/1596]  eta: 0:39:12  lr: 0.001658  loss: 0.2855 (0.5103)  loss_classifier: 0.1153 (0.2747)  loss_box_reg: 0.1536 (0.1970)  loss_objectness: 0.0162 (0.0308)  loss_rpn_box_reg: 0.0050 (0.0077)  time: 1.8440  data: 0.0980  max mem: 6208
# Epoch: [0]  [ 340/1596]  eta: 0:38:54  lr: 0.001708  loss: 0.2921 (0.5040)  loss_classifier: 0.1288 (0.2702)  loss_box_reg: 0.1462 (0.1957)  loss_objectness: 0.0136 (0.0305)  loss_rpn_box_reg: 0.0042 (0.0077)  time: 1.8585  data: 0.1136  max mem: 6208
# Epoch: [0]  [ 350/1596]  eta: 0:38:33  lr: 0.001758  loss: 0.2688 (0.4974)  loss_classifier: 0.1165 (0.2657)  loss_box_reg: 0.1343 (0.1941)  loss_objectness: 0.0140 (0.0300)  loss_rpn_box_reg: 0.0044 (0.0076)  time: 1.8390  data: 0.1174  max mem: 6208
# Epoch: [0]  [ 360/1596]  eta: 0:38:13  lr: 0.001808  loss: 0.2841 (0.4930)  loss_classifier: 0.1182 (0.2622)  loss_box_reg: 0.1392 (0.1930)  loss_objectness: 0.0147 (0.0301)  loss_rpn_box_reg: 0.0044 (0.0076)  time: 1.8029  data: 0.1000  max mem: 6208
# Epoch: [0]  [ 370/1596]  eta: 0:37:53  lr: 0.001858  loss: 0.3143 (0.4879)  loss_classifier: 0.1324 (0.2586)  loss_box_reg: 0.1571 (0.1917)  loss_objectness: 0.0155 (0.0299)  loss_rpn_box_reg: 0.0067 (0.0076)  time: 1.8084  data: 0.1027  max mem: 6208
# Epoch: [0]  [ 380/1596]  eta: 0:37:34  lr: 0.001908  loss: 0.2528 (0.4816)  loss_classifier: 0.1067 (0.2545)  loss_box_reg: 0.1314 (0.1900)  loss_objectness: 0.0125 (0.0295)  loss_rpn_box_reg: 0.0051 (0.0076)  time: 1.8225  data: 0.1018  max mem: 6208
# Epoch: [0]  [ 390/1596]  eta: 0:37:15  lr: 0.001958  loss: 0.2673 (0.4773)  loss_classifier: 0.1096 (0.2514)  loss_box_reg: 0.1384 (0.1892)  loss_objectness: 0.0135 (0.0291)  loss_rpn_box_reg: 0.0048 (0.0076)  time: 1.8450  data: 0.0948  max mem: 6208
# Epoch: [0]  [ 400/1596]  eta: 0:36:54  lr: 0.002008  loss: 0.2730 (0.4722)  loss_classifier: 0.1164 (0.2481)  loss_box_reg: 0.1344 (0.1877)  loss_objectness: 0.0120 (0.0289)  loss_rpn_box_reg: 0.0044 (0.0075)  time: 1.8147  data: 0.0921  max mem: 6208
# Epoch: [0]  [ 410/1596]  eta: 0:36:35  lr: 0.002058  loss: 0.2594 (0.4679)  loss_classifier: 0.1141 (0.2451)  loss_box_reg: 0.1258 (0.1867)  loss_objectness: 0.0120 (0.0287)  loss_rpn_box_reg: 0.0048 (0.0074)  time: 1.7990  data: 0.0882  max mem: 6208
# Epoch: [0]  [ 420/1596]  eta: 0:36:17  lr: 0.002108  loss: 0.2615 (0.4629)  loss_classifier: 0.1111 (0.2418)  loss_box_reg: 0.1231 (0.1851)  loss_objectness: 0.0136 (0.0285)  loss_rpn_box_reg: 0.0048 (0.0074)  time: 1.8386  data: 0.1036  max mem: 6208
# Epoch: [0]  [ 430/1596]  eta: 0:35:58  lr: 0.002158  loss: 0.2599 (0.4581)  loss_classifier: 0.1077 (0.2388)  loss_box_reg: 0.1171 (0.1836)  loss_objectness: 0.0111 (0.0282)  loss_rpn_box_reg: 0.0039 (0.0075)  time: 1.8500  data: 0.1078  max mem: 6208
# Epoch: [0]  [ 440/1596]  eta: 0:35:40  lr: 0.002208  loss: 0.2500 (0.4529)  loss_classifier: 0.1054 (0.2357)  loss_box_reg: 0.1162 (0.1820)  loss_objectness: 0.0088 (0.0278)  loss_rpn_box_reg: 0.0033 (0.0074)  time: 1.8542  data: 0.1023  max mem: 6208
# Epoch: [0]  [ 450/1596]  eta: 0:35:21  lr: 0.002258  loss: 0.2392 (0.4489)  loss_classifier: 0.0995 (0.2328)  loss_box_reg: 0.1132 (0.1808)  loss_objectness: 0.0107 (0.0278)  loss_rpn_box_reg: 0.0034 (0.0074)  time: 1.8504  data: 0.1017  max mem: 6208
# Epoch: [0]  [ 460/1596]  eta: 0:35:03  lr: 0.002308  loss: 0.2371 (0.4449)  loss_classifier: 0.0995 (0.2303)  loss_box_reg: 0.1065 (0.1793)  loss_objectness: 0.0140 (0.0278)  loss_rpn_box_reg: 0.0043 (0.0075)  time: 1.8635  data: 0.1040  max mem: 6208
# Epoch: [0]  [ 470/1596]  eta: 0:34:44  lr: 0.002358  loss: 0.2284 (0.4408)  loss_classifier: 0.1015 (0.2277)  loss_box_reg: 0.1081 (0.1781)  loss_objectness: 0.0166 (0.0275)  loss_rpn_box_reg: 0.0043 (0.0075)  time: 1.8559  data: 0.1073  max mem: 6208
# Epoch: [0]  [ 480/1596]  eta: 0:34:25  lr: 0.002408  loss: 0.2391 (0.4368)  loss_classifier: 0.1006 (0.2250)  loss_box_reg: 0.1122 (0.1768)  loss_objectness: 0.0168 (0.0275)  loss_rpn_box_reg: 0.0052 (0.0075)  time: 1.8270  data: 0.1041  max mem: 6208
# Epoch: [0]  [ 490/1596]  eta: 0:34:06  lr: 0.002458  loss: 0.2399 (0.4323)  loss_classifier: 0.1006 (0.2224)  loss_box_reg: 0.1102 (0.1753)  loss_objectness: 0.0130 (0.0271)  loss_rpn_box_reg: 0.0038 (0.0074)  time: 1.8237  data: 0.0980  max mem: 6208
# Epoch: [0]  [ 500/1596]  eta: 0:33:47  lr: 0.002507  loss: 0.2251 (0.4290)  loss_classifier: 0.1077 (0.2202)  loss_box_reg: 0.1129 (0.1742)  loss_objectness: 0.0130 (0.0271)  loss_rpn_box_reg: 0.0035 (0.0075)  time: 1.8245  data: 0.0978  max mem: 6208
# Epoch: [0]  [ 510/1596]  eta: 0:33:28  lr: 0.002557  loss: 0.2362 (0.4252)  loss_classifier: 0.0996 (0.2179)  loss_box_reg: 0.1103 (0.1729)  loss_objectness: 0.0141 (0.0270)  loss_rpn_box_reg: 0.0043 (0.0075)  time: 1.8301  data: 0.1035  max mem: 6208
# Epoch: [0]  [ 520/1596]  eta: 0:33:09  lr: 0.002607  loss: 0.2333 (0.4216)  loss_classifier: 0.1006 (0.2157)  loss_box_reg: 0.1075 (0.1717)  loss_objectness: 0.0135 (0.0267)  loss_rpn_box_reg: 0.0055 (0.0075)  time: 1.8367  data: 0.1074  max mem: 6208
# Epoch: [0]  [ 530/1596]  eta: 0:32:50  lr: 0.002657  loss: 0.2205 (0.4179)  loss_classifier: 0.0995 (0.2135)  loss_box_reg: 0.1072 (0.1705)  loss_objectness: 0.0106 (0.0265)  loss_rpn_box_reg: 0.0043 (0.0074)  time: 1.8315  data: 0.1038  max mem: 6208
# Epoch: [0]  [ 540/1596]  eta: 0:32:31  lr: 0.002707  loss: 0.2205 (0.4149)  loss_classifier: 0.0995 (0.2115)  loss_box_reg: 0.1072 (0.1695)  loss_objectness: 0.0097 (0.0265)  loss_rpn_box_reg: 0.0029 (0.0075)  time: 1.8186  data: 0.0984  max mem: 6208
# Epoch: [0]  [ 550/1596]  eta: 0:32:13  lr: 0.002757  loss: 0.1919 (0.4113)  loss_classifier: 0.0858 (0.2093)  loss_box_reg: 0.0965 (0.1683)  loss_objectness: 0.0109 (0.0263)  loss_rpn_box_reg: 0.0032 (0.0074)  time: 1.8428  data: 0.1082  max mem: 6208
# Epoch: [0]  [ 560/1596]  eta: 0:31:54  lr: 0.002807  loss: 0.1931 (0.4086)  loss_classifier: 0.0858 (0.2074)  loss_box_reg: 0.0965 (0.1673)  loss_objectness: 0.0116 (0.0264)  loss_rpn_box_reg: 0.0042 (0.0075)  time: 1.8484  data: 0.1091  max mem: 6208
# Epoch: [0]  [ 570/1596]  eta: 0:31:35  lr: 0.002857  loss: 0.2272 (0.4059)  loss_classifier: 0.0999 (0.2057)  loss_box_reg: 0.0970 (0.1663)  loss_objectness: 0.0162 (0.0264)  loss_rpn_box_reg: 0.0053 (0.0075)  time: 1.8309  data: 0.1004  max mem: 6208
# Epoch: [0]  [ 580/1596]  eta: 0:31:16  lr: 0.002907  loss: 0.2486 (0.4034)  loss_classifier: 0.1062 (0.2041)  loss_box_reg: 0.1080 (0.1654)  loss_objectness: 0.0213 (0.0264)  loss_rpn_box_reg: 0.0053 (0.0076)  time: 1.8122  data: 0.0886  max mem: 6208
# Epoch: [0]  [ 590/1596]  eta: 0:30:57  lr: 0.002957  loss: 0.2587 (0.4006)  loss_classifier: 0.1062 (0.2023)  loss_box_reg: 0.1080 (0.1645)  loss_objectness: 0.0127 (0.0262)  loss_rpn_box_reg: 0.0040 (0.0075)  time: 1.8147  data: 0.0936  max mem: 6208
# Epoch: [0]  [ 600/1596]  eta: 0:30:39  lr: 0.003007  loss: 0.2059 (0.3975)  loss_classifier: 0.0891 (0.2006)  loss_box_reg: 0.1073 (0.1635)  loss_objectness: 0.0084 (0.0259)  loss_rpn_box_reg: 0.0036 (0.0075)  time: 1.8362  data: 0.1024  max mem: 6208
# Epoch: [0]  [ 610/1596]  eta: 0:30:20  lr: 0.003057  loss: 0.2059 (0.3949)  loss_classifier: 0.0887 (0.1990)  loss_box_reg: 0.1052 (0.1627)  loss_objectness: 0.0085 (0.0257)  loss_rpn_box_reg: 0.0034 (0.0074)  time: 1.8473  data: 0.0976  max mem: 6208
# Epoch: [0]  [ 620/1596]  eta: 0:30:02  lr: 0.003107  loss: 0.2158 (0.3931)  loss_classifier: 0.0988 (0.1976)  loss_box_reg: 0.1121 (0.1621)  loss_objectness: 0.0130 (0.0258)  loss_rpn_box_reg: 0.0053 (0.0076)  time: 1.8570  data: 0.1039  max mem: 6208
# Epoch: [0]  [ 630/1596]  eta: 0:29:43  lr: 0.003157  loss: 0.2202 (0.3903)  loss_classifier: 0.0988 (0.1959)  loss_box_reg: 0.1088 (0.1612)  loss_objectness: 0.0128 (0.0256)  loss_rpn_box_reg: 0.0052 (0.0076)  time: 1.8290  data: 0.0977  max mem: 6208
# Epoch: [0]  [ 640/1596]  eta: 0:29:24  lr: 0.003207  loss: 0.2174 (0.3877)  loss_classifier: 0.0956 (0.1944)  loss_box_reg: 0.1071 (0.1604)  loss_objectness: 0.0095 (0.0254)  loss_rpn_box_reg: 0.0033 (0.0076)  time: 1.8049  data: 0.0918  max mem: 6208
# Epoch: [0]  [ 650/1596]  eta: 0:29:05  lr: 0.003257  loss: 0.2020 (0.3848)  loss_classifier: 0.0905 (0.1927)  loss_box_reg: 0.0991 (0.1593)  loss_objectness: 0.0082 (0.0253)  loss_rpn_box_reg: 0.0031 (0.0076)  time: 1.8164  data: 0.0942  max mem: 6208
# Epoch: [0]  [ 660/1596]  eta: 0:28:46  lr: 0.003307  loss: 0.1940 (0.3822)  loss_classifier: 0.0855 (0.1911)  loss_box_reg: 0.1010 (0.1584)  loss_objectness: 0.0080 (0.0251)  loss_rpn_box_reg: 0.0029 (0.0076)  time: 1.8029  data: 0.0860  max mem: 6208
# Epoch: [0]  [ 670/1596]  eta: 0:28:27  lr: 0.003357  loss: 0.2194 (0.3799)  loss_classifier: 0.0879 (0.1896)  loss_box_reg: 0.1077 (0.1576)  loss_objectness: 0.0118 (0.0250)  loss_rpn_box_reg: 0.0037 (0.0077)  time: 1.8042  data: 0.0877  max mem: 6208
# Epoch: [0]  [ 680/1596]  eta: 0:28:08  lr: 0.003407  loss: 0.2137 (0.3775)  loss_classifier: 0.0804 (0.1880)  loss_box_reg: 0.0943 (0.1567)  loss_objectness: 0.0118 (0.0251)  loss_rpn_box_reg: 0.0037 (0.0077)  time: 1.8243  data: 0.1007  max mem: 6208
# Epoch: [0]  [ 690/1596]  eta: 0:27:51  lr: 0.003457  loss: 0.2137 (0.3752)  loss_classifier: 0.0945 (0.1867)  loss_box_reg: 0.0898 (0.1558)  loss_objectness: 0.0112 (0.0250)  loss_rpn_box_reg: 0.0029 (0.0076)  time: 1.8791  data: 0.1330  max mem: 6237
# Epoch: [0]  [ 700/1596]  eta: 0:27:33  lr: 0.003506  loss: 0.2067 (0.3727)  loss_classifier: 0.0945 (0.1853)  loss_box_reg: 0.0897 (0.1550)  loss_objectness: 0.0124 (0.0248)  loss_rpn_box_reg: 0.0029 (0.0076)  time: 1.8936  data: 0.1362  max mem: 6237
# Epoch: [0]  [ 710/1596]  eta: 0:27:14  lr: 0.003556  loss: 0.1856 (0.3705)  loss_classifier: 0.0811 (0.1840)  loss_box_reg: 0.0885 (0.1542)  loss_objectness: 0.0107 (0.0247)  loss_rpn_box_reg: 0.0038 (0.0076)  time: 1.8422  data: 0.1091  max mem: 6237
# Epoch: [0]  [ 720/1596]  eta: 0:26:56  lr: 0.003606  loss: 0.1980 (0.3682)  loss_classifier: 0.0847 (0.1827)  loss_box_reg: 0.0957 (0.1535)  loss_objectness: 0.0092 (0.0245)  loss_rpn_box_reg: 0.0038 (0.0076)  time: 1.8546  data: 0.1046  max mem: 6237
# Epoch: [0]  [ 730/1596]  eta: 0:26:38  lr: 0.003656  loss: 0.1801 (0.3658)  loss_classifier: 0.0806 (0.1813)  loss_box_reg: 0.0959 (0.1527)  loss_objectness: 0.0084 (0.0243)  loss_rpn_box_reg: 0.0035 (0.0075)  time: 1.8738  data: 0.1155  max mem: 6237
# Epoch: [0]  [ 740/1596]  eta: 0:26:20  lr: 0.003706  loss: 0.1978 (0.3639)  loss_classifier: 0.0841 (0.1801)  loss_box_reg: 0.0974 (0.1520)  loss_objectness: 0.0116 (0.0242)  loss_rpn_box_reg: 0.0035 (0.0075)  time: 1.8632  data: 0.1156  max mem: 6237
# Epoch: [0]  [ 750/1596]  eta: 0:26:01  lr: 0.003756  loss: 0.1978 (0.3616)  loss_classifier: 0.0832 (0.1788)  loss_box_reg: 0.0995 (0.1513)  loss_objectness: 0.0116 (0.0240)  loss_rpn_box_reg: 0.0035 (0.0075)  time: 1.8665  data: 0.1087  max mem: 6237
# Epoch: [0]  [ 760/1596]  eta: 0:25:44  lr: 0.003806  loss: 0.1946 (0.3598)  loss_classifier: 0.0793 (0.1776)  loss_box_reg: 0.0938 (0.1505)  loss_objectness: 0.0080 (0.0241)  loss_rpn_box_reg: 0.0043 (0.0076)  time: 1.8970  data: 0.1119  max mem: 6265
# Epoch: [0]  [ 770/1596]  eta: 0:25:25  lr: 0.003856  loss: 0.1858 (0.3579)  loss_classifier: 0.0824 (0.1765)  loss_box_reg: 0.0863 (0.1499)  loss_objectness: 0.0107 (0.0239)  loss_rpn_box_reg: 0.0034 (0.0076)  time: 1.8716  data: 0.1074  max mem: 6265
# Epoch: [0]  [ 780/1596]  eta: 0:25:07  lr: 0.003906  loss: 0.1962 (0.3562)  loss_classifier: 0.0815 (0.1754)  loss_box_reg: 0.1060 (0.1495)  loss_objectness: 0.0099 (0.0238)  loss_rpn_box_reg: 0.0032 (0.0075)  time: 1.8408  data: 0.1121  max mem: 6265
# Epoch: [0]  [ 790/1596]  eta: 0:24:48  lr: 0.003956  loss: 0.1914 (0.3542)  loss_classifier: 0.0812 (0.1742)  loss_box_reg: 0.0992 (0.1488)  loss_objectness: 0.0072 (0.0236)  loss_rpn_box_reg: 0.0030 (0.0075)  time: 1.8411  data: 0.1118  max mem: 6265
# Epoch: [0]  [ 800/1596]  eta: 0:24:29  lr: 0.004006  loss: 0.2022 (0.3528)  loss_classifier: 0.0888 (0.1734)  loss_box_reg: 0.0921 (0.1483)  loss_objectness: 0.0076 (0.0236)  loss_rpn_box_reg: 0.0034 (0.0075)  time: 1.8333  data: 0.1056  max mem: 6265
# Epoch: [0]  [ 810/1596]  eta: 0:24:11  lr: 0.004056  loss: 0.2084 (0.3510)  loss_classifier: 0.1057 (0.1725)  loss_box_reg: 0.0914 (0.1476)  loss_objectness: 0.0135 (0.0235)  loss_rpn_box_reg: 0.0037 (0.0075)  time: 1.8413  data: 0.1038  max mem: 6265
# Epoch: [0]  [ 820/1596]  eta: 0:23:52  lr: 0.004106  loss: 0.1807 (0.3491)  loss_classifier: 0.0743 (0.1714)  loss_box_reg: 0.0814 (0.1469)  loss_objectness: 0.0114 (0.0234)  loss_rpn_box_reg: 0.0026 (0.0074)  time: 1.8407  data: 0.1043  max mem: 6265
# Epoch: [0]  [ 830/1596]  eta: 0:23:34  lr: 0.004156  loss: 0.2063 (0.3475)  loss_classifier: 0.0843 (0.1705)  loss_box_reg: 0.0968 (0.1463)  loss_objectness: 0.0074 (0.0232)  loss_rpn_box_reg: 0.0030 (0.0074)  time: 1.8613  data: 0.1122  max mem: 6265
# Epoch: [0]  [ 840/1596]  eta: 0:23:16  lr: 0.004206  loss: 0.2095 (0.3460)  loss_classifier: 0.0900 (0.1696)  loss_box_reg: 0.0999 (0.1458)  loss_objectness: 0.0104 (0.0232)  loss_rpn_box_reg: 0.0032 (0.0074)  time: 1.8978  data: 0.1254  max mem: 6265
# Epoch: [0]  [ 850/1596]  eta: 0:22:58  lr: 0.004256  loss: 0.1852 (0.3445)  loss_classifier: 0.0886 (0.1687)  loss_box_reg: 0.0865 (0.1452)  loss_objectness: 0.0140 (0.0232)  loss_rpn_box_reg: 0.0039 (0.0074)  time: 1.8751  data: 0.1140  max mem: 6265
# Epoch: [0]  [ 860/1596]  eta: 0:22:40  lr: 0.004306  loss: 0.1976 (0.3427)  loss_classifier: 0.0809 (0.1677)  loss_box_reg: 0.0906 (0.1447)  loss_objectness: 0.0083 (0.0230)  loss_rpn_box_reg: 0.0035 (0.0074)  time: 1.8698  data: 0.1016  max mem: 6265
# Epoch: [0]  [ 870/1596]  eta: 0:22:22  lr: 0.004356  loss: 0.1904 (0.3410)  loss_classifier: 0.0801 (0.1667)  loss_box_reg: 0.0906 (0.1441)  loss_objectness: 0.0060 (0.0229)  loss_rpn_box_reg: 0.0026 (0.0073)  time: 1.8979  data: 0.1158  max mem: 6265
# Epoch: [0]  [ 880/1596]  eta: 0:22:04  lr: 0.004406  loss: 0.2051 (0.3403)  loss_classifier: 0.1008 (0.1662)  loss_box_reg: 0.0992 (0.1438)  loss_objectness: 0.0096 (0.0230)  loss_rpn_box_reg: 0.0044 (0.0074)  time: 1.8916  data: 0.1199  max mem: 6265
# Epoch: [0]  [ 890/1596]  eta: 0:21:45  lr: 0.004456  loss: 0.2322 (0.3388)  loss_classifier: 0.0951 (0.1653)  loss_box_reg: 0.1029 (0.1433)  loss_objectness: 0.0132 (0.0229)  loss_rpn_box_reg: 0.0044 (0.0073)  time: 1.8935  data: 0.1173  max mem: 6265
# Epoch: [0]  [ 900/1596]  eta: 0:21:27  lr: 0.004505  loss: 0.1863 (0.3375)  loss_classifier: 0.0777 (0.1644)  loss_box_reg: 0.0904 (0.1429)  loss_objectness: 0.0113 (0.0228)  loss_rpn_box_reg: 0.0032 (0.0073)  time: 1.8810  data: 0.1168  max mem: 6265
# Epoch: [0]  [ 910/1596]  eta: 0:21:09  lr: 0.004555  loss: 0.1984 (0.3360)  loss_classifier: 0.0819 (0.1636)  loss_box_reg: 0.0948 (0.1424)  loss_objectness: 0.0099 (0.0228)  loss_rpn_box_reg: 0.0034 (0.0073)  time: 1.8643  data: 0.1097  max mem: 6265
# Epoch: [0]  [ 920/1596]  eta: 0:20:50  lr: 0.004605  loss: 0.1825 (0.3345)  loss_classifier: 0.0819 (0.1627)  loss_box_reg: 0.0878 (0.1419)  loss_objectness: 0.0092 (0.0226)  loss_rpn_box_reg: 0.0031 (0.0073)  time: 1.8671  data: 0.1042  max mem: 6265
# Epoch: [0]  [ 930/1596]  eta: 0:20:32  lr: 0.004655  loss: 0.1956 (0.3334)  loss_classifier: 0.0871 (0.1621)  loss_box_reg: 0.0983 (0.1415)  loss_objectness: 0.0105 (0.0226)  loss_rpn_box_reg: 0.0037 (0.0073)  time: 1.8687  data: 0.1122  max mem: 6265
# Epoch: [0]  [ 940/1596]  eta: 0:20:14  lr: 0.004705  loss: 0.1945 (0.3320)  loss_classifier: 0.0877 (0.1613)  loss_box_reg: 0.0991 (0.1411)  loss_objectness: 0.0099 (0.0224)  loss_rpn_box_reg: 0.0032 (0.0072)  time: 1.8895  data: 0.1171  max mem: 6265
# Epoch: [0]  [ 950/1596]  eta: 0:19:56  lr: 0.004755  loss: 0.1907 (0.3304)  loss_classifier: 0.0841 (0.1605)  loss_box_reg: 0.0877 (0.1405)  loss_objectness: 0.0066 (0.0223)  loss_rpn_box_reg: 0.0027 (0.0072)  time: 1.8914  data: 0.1155  max mem: 6265
# Epoch: [0]  [ 960/1596]  eta: 0:19:37  lr: 0.004805  loss: 0.1961 (0.3293)  loss_classifier: 0.0914 (0.1598)  loss_box_reg: 0.0877 (0.1401)  loss_objectness: 0.0090 (0.0222)  loss_rpn_box_reg: 0.0038 (0.0072)  time: 1.8748  data: 0.1150  max mem: 6265
# Epoch: [0]  [ 970/1596]  eta: 0:19:19  lr: 0.004855  loss: 0.2071 (0.3280)  loss_classifier: 0.0924 (0.1590)  loss_box_reg: 0.0959 (0.1396)  loss_objectness: 0.0103 (0.0221)  loss_rpn_box_reg: 0.0042 (0.0072)  time: 1.8875  data: 0.1162  max mem: 6265
# Epoch: [0]  [ 980/1596]  eta: 0:19:00  lr: 0.004905  loss: 0.1860 (0.3265)  loss_classifier: 0.0809 (0.1583)  loss_box_reg: 0.0912 (0.1391)  loss_objectness: 0.0097 (0.0220)  loss_rpn_box_reg: 0.0039 (0.0072)  time: 1.8751  data: 0.1148  max mem: 6265
# Epoch: [0]  [ 990/1596]  eta: 0:18:42  lr: 0.004955  loss: 0.1724 (0.3251)  loss_classifier: 0.0753 (0.1574)  loss_box_reg: 0.0858 (0.1386)  loss_objectness: 0.0089 (0.0220)  loss_rpn_box_reg: 0.0032 (0.0071)  time: 1.8454  data: 0.1024  max mem: 6265
# Epoch: [0]  [1000/1596]  eta: 0:18:23  lr: 0.005000  loss: 0.1826 (0.3241)  loss_classifier: 0.0799 (0.1566)  loss_box_reg: 0.0881 (0.1382)  loss_objectness: 0.0092 (0.0221)  loss_rpn_box_reg: 0.0032 (0.0072)  time: 1.8600  data: 0.1084  max mem: 6265
# Epoch: [0]  [1010/1596]  eta: 0:18:05  lr: 0.005000  loss: 0.1948 (0.3230)  loss_classifier: 0.0800 (0.1559)  loss_box_reg: 0.0969 (0.1378)  loss_objectness: 0.0120 (0.0221)  loss_rpn_box_reg: 0.0044 (0.0072)  time: 1.8752  data: 0.1188  max mem: 6265
# Epoch: [0]  [1020/1596]  eta: 0:17:47  lr: 0.005000  loss: 0.1772 (0.3217)  loss_classifier: 0.0721 (0.1551)  loss_box_reg: 0.0936 (0.1373)  loss_objectness: 0.0120 (0.0220)  loss_rpn_box_reg: 0.0035 (0.0072)  time: 1.8759  data: 0.1226  max mem: 6265
# Epoch: [0]  [1030/1596]  eta: 0:17:28  lr: 0.005000  loss: 0.1740 (0.3205)  loss_classifier: 0.0739 (0.1545)  loss_box_reg: 0.0881 (0.1369)  loss_objectness: 0.0118 (0.0219)  loss_rpn_box_reg: 0.0037 (0.0072)  time: 1.8868  data: 0.1247  max mem: 6265
# Epoch: [0]  [1040/1596]  eta: 0:17:10  lr: 0.005000  loss: 0.1758 (0.3192)  loss_classifier: 0.0779 (0.1538)  loss_box_reg: 0.0860 (0.1364)  loss_objectness: 0.0104 (0.0219)  loss_rpn_box_reg: 0.0037 (0.0071)  time: 1.8650  data: 0.1223  max mem: 6265
# Epoch: [0]  [1050/1596]  eta: 0:16:52  lr: 0.005000  loss: 0.1694 (0.3179)  loss_classifier: 0.0820 (0.1531)  loss_box_reg: 0.0826 (0.1359)  loss_objectness: 0.0079 (0.0218)  loss_rpn_box_reg: 0.0031 (0.0071)  time: 1.8743  data: 0.1227  max mem: 6265
# Epoch: [0]  [1060/1596]  eta: 0:16:33  lr: 0.005000  loss: 0.1798 (0.3167)  loss_classifier: 0.0773 (0.1524)  loss_box_reg: 0.0860 (0.1356)  loss_objectness: 0.0081 (0.0217)  loss_rpn_box_reg: 0.0033 (0.0071)  time: 1.9300  data: 0.1208  max mem: 6265
# Epoch: [0]  [1070/1596]  eta: 0:16:15  lr: 0.005000  loss: 0.2113 (0.3164)  loss_classifier: 0.0900 (0.1519)  loss_box_reg: 0.0965 (0.1353)  loss_objectness: 0.0131 (0.0219)  loss_rpn_box_reg: 0.0047 (0.0073)  time: 1.9320  data: 0.1284  max mem: 6265
# Epoch: [0]  [1080/1596]  eta: 0:15:56  lr: 0.005000  loss: 0.2266 (0.3156)  loss_classifier: 0.0957 (0.1513)  loss_box_reg: 0.1002 (0.1350)  loss_objectness: 0.0149 (0.0219)  loss_rpn_box_reg: 0.0050 (0.0073)  time: 1.8632  data: 0.1207  max mem: 6265
# Epoch: [0]  [1090/1596]  eta: 0:15:38  lr: 0.005000  loss: 0.1894 (0.3146)  loss_classifier: 0.0778 (0.1508)  loss_box_reg: 0.0969 (0.1346)  loss_objectness: 0.0164 (0.0219)  loss_rpn_box_reg: 0.0040 (0.0073)  time: 1.8371  data: 0.1101  max mem: 6265
# Epoch: [0]  [1100/1596]  eta: 0:15:19  lr: 0.005000  loss: 0.1835 (0.3133)  loss_classifier: 0.0700 (0.1500)  loss_box_reg: 0.0844 (0.1341)  loss_objectness: 0.0130 (0.0219)  loss_rpn_box_reg: 0.0040 (0.0073)  time: 1.8662  data: 0.1176  max mem: 6265
# Epoch: [0]  [1110/1596]  eta: 0:15:01  lr: 0.005000  loss: 0.1504 (0.3123)  loss_classifier: 0.0641 (0.1493)  loss_box_reg: 0.0729 (0.1337)  loss_objectness: 0.0115 (0.0219)  loss_rpn_box_reg: 0.0042 (0.0074)  time: 1.8937  data: 0.1267  max mem: 6265
# Epoch: [0]  [1120/1596]  eta: 0:14:43  lr: 0.005000  loss: 0.1909 (0.3112)  loss_classifier: 0.0744 (0.1487)  loss_box_reg: 0.0839 (0.1333)  loss_objectness: 0.0121 (0.0218)  loss_rpn_box_reg: 0.0043 (0.0073)  time: 1.8837  data: 0.1168  max mem: 6265
# Epoch: [0]  [1130/1596]  eta: 0:14:24  lr: 0.005000  loss: 0.1781 (0.3102)  loss_classifier: 0.0776 (0.1481)  loss_box_reg: 0.0867 (0.1330)  loss_objectness: 0.0084 (0.0217)  loss_rpn_box_reg: 0.0037 (0.0073)  time: 1.8647  data: 0.1065  max mem: 6265
# Epoch: [0]  [1140/1596]  eta: 0:14:06  lr: 0.005000  loss: 0.1777 (0.3092)  loss_classifier: 0.0776 (0.1476)  loss_box_reg: 0.0871 (0.1326)  loss_objectness: 0.0093 (0.0217)  loss_rpn_box_reg: 0.0037 (0.0073)  time: 1.8762  data: 0.1118  max mem: 6265
# Epoch: [0]  [1150/1596]  eta: 0:13:47  lr: 0.005000  loss: 0.1650 (0.3081)  loss_classifier: 0.0737 (0.1469)  loss_box_reg: 0.0830 (0.1322)  loss_objectness: 0.0096 (0.0216)  loss_rpn_box_reg: 0.0029 (0.0073)  time: 1.8860  data: 0.1164  max mem: 6265
# Epoch: [0]  [1160/1596]  eta: 0:13:29  lr: 0.005000  loss: 0.1634 (0.3070)  loss_classifier: 0.0737 (0.1464)  loss_box_reg: 0.0829 (0.1318)  loss_objectness: 0.0078 (0.0215)  loss_rpn_box_reg: 0.0039 (0.0073)  time: 1.9014  data: 0.1173  max mem: 6265
# Epoch: [0]  [1170/1596]  eta: 0:13:10  lr: 0.005000  loss: 0.1801 (0.3062)  loss_classifier: 0.0799 (0.1458)  loss_box_reg: 0.0837 (0.1315)  loss_objectness: 0.0107 (0.0215)  loss_rpn_box_reg: 0.0047 (0.0073)  time: 1.8762  data: 0.1097  max mem: 6265
# Epoch: [0]  [1180/1596]  eta: 0:12:52  lr: 0.005000  loss: 0.1794 (0.3050)  loss_classifier: 0.0705 (0.1452)  loss_box_reg: 0.0866 (0.1311)  loss_objectness: 0.0087 (0.0214)  loss_rpn_box_reg: 0.0033 (0.0073)  time: 1.8595  data: 0.1133  max mem: 6265
# Epoch: [0]  [1190/1596]  eta: 0:12:33  lr: 0.005000  loss: 0.1701 (0.3041)  loss_classifier: 0.0719 (0.1447)  loss_box_reg: 0.0856 (0.1307)  loss_objectness: 0.0083 (0.0214)  loss_rpn_box_reg: 0.0033 (0.0073)  time: 1.8711  data: 0.1203  max mem: 6265
# Epoch: [0]  [1200/1596]  eta: 0:12:15  lr: 0.005000  loss: 0.1911 (0.3031)  loss_classifier: 0.0749 (0.1442)  loss_box_reg: 0.0886 (0.1304)  loss_objectness: 0.0098 (0.0213)  loss_rpn_box_reg: 0.0038 (0.0073)  time: 1.8364  data: 0.1061  max mem: 6265
# Epoch: [0]  [1210/1596]  eta: 0:11:56  lr: 0.005000  loss: 0.1968 (0.3027)  loss_classifier: 0.0825 (0.1438)  loss_box_reg: 0.0948 (0.1302)  loss_objectness: 0.0087 (0.0213)  loss_rpn_box_reg: 0.0041 (0.0073)  time: 1.8446  data: 0.1176  max mem: 6265
# Epoch: [0]  [1220/1596]  eta: 0:11:38  lr: 0.005000  loss: 0.1968 (0.3019)  loss_classifier: 0.0786 (0.1434)  loss_box_reg: 0.0977 (0.1300)  loss_objectness: 0.0093 (0.0213)  loss_rpn_box_reg: 0.0041 (0.0073)  time: 1.9235  data: 0.1380  max mem: 6265
# Epoch: [0]  [1230/1596]  eta: 0:11:19  lr: 0.005000  loss: 0.1715 (0.3010)  loss_classifier: 0.0758 (0.1428)  loss_box_reg: 0.0861 (0.1296)  loss_objectness: 0.0091 (0.0212)  loss_rpn_box_reg: 0.0028 (0.0073)  time: 1.9364  data: 0.1289  max mem: 6265
# Epoch: [0]  [1240/1596]  eta: 0:11:02  lr: 0.005000  loss: 0.1763 (0.3003)  loss_classifier: 0.0747 (0.1424)  loss_box_reg: 0.0851 (0.1293)  loss_objectness: 0.0116 (0.0212)  loss_rpn_box_reg: 0.0028 (0.0073)  time: 2.0364  data: 0.2256  max mem: 6361
# Epoch: [0]  [1250/1596]  eta: 0:10:43  lr: 0.005000  loss: 0.1763 (0.2993)  loss_classifier: 0.0708 (0.1418)  loss_box_reg: 0.0783 (0.1290)  loss_objectness: 0.0112 (0.0212)  loss_rpn_box_reg: 0.0038 (0.0073)  time: 2.0394  data: 0.2178  max mem: 6361
# Epoch: [0]  [1260/1596]  eta: 0:10:25  lr: 0.005000  loss: 0.1733 (0.2986)  loss_classifier: 0.0765 (0.1414)  loss_box_reg: 0.0822 (0.1288)  loss_objectness: 0.0102 (0.0211)  loss_rpn_box_reg: 0.0041 (0.0073)  time: 1.9017  data: 0.1055  max mem: 6361
# Epoch: [0]  [1270/1596]  eta: 0:10:06  lr: 0.005000  loss: 0.1797 (0.2979)  loss_classifier: 0.0784 (0.1410)  loss_box_reg: 0.0934 (0.1285)  loss_objectness: 0.0102 (0.0211)  loss_rpn_box_reg: 0.0036 (0.0073)  time: 1.9002  data: 0.1229  max mem: 6361
# Epoch: [0]  [1280/1596]  eta: 0:09:48  lr: 0.005000  loss: 0.1846 (0.2973)  loss_classifier: 0.0784 (0.1406)  loss_box_reg: 0.0934 (0.1282)  loss_objectness: 0.0153 (0.0211)  loss_rpn_box_reg: 0.0032 (0.0073)  time: 1.8979  data: 0.1294  max mem: 6361
# Epoch: [0]  [1290/1596]  eta: 0:09:29  lr: 0.005000  loss: 0.2058 (0.2967)  loss_classifier: 0.0807 (0.1403)  loss_box_reg: 0.0970 (0.1280)  loss_objectness: 0.0153 (0.0211)  loss_rpn_box_reg: 0.0041 (0.0073)  time: 1.8834  data: 0.1106  max mem: 6361
# Epoch: [0]  [1300/1596]  eta: 0:09:11  lr: 0.005000  loss: 0.2023 (0.2961)  loss_classifier: 0.0807 (0.1398)  loss_box_reg: 0.0972 (0.1278)  loss_objectness: 0.0144 (0.0211)  loss_rpn_box_reg: 0.0047 (0.0073)  time: 1.8877  data: 0.1146  max mem: 6361
# Epoch: [0]  [1310/1596]  eta: 0:08:52  lr: 0.005000  loss: 0.1896 (0.2954)  loss_classifier: 0.0828 (0.1394)  loss_box_reg: 0.0874 (0.1275)  loss_objectness: 0.0164 (0.0211)  loss_rpn_box_reg: 0.0048 (0.0073)  time: 1.8675  data: 0.1169  max mem: 6361
# Epoch: [0]  [1320/1596]  eta: 0:08:33  lr: 0.005000  loss: 0.1889 (0.2946)  loss_classifier: 0.0796 (0.1390)  loss_box_reg: 0.0818 (0.1272)  loss_objectness: 0.0147 (0.0211)  loss_rpn_box_reg: 0.0036 (0.0073)  time: 1.8661  data: 0.1101  max mem: 6361
# Epoch: [0]  [1330/1596]  eta: 0:08:15  lr: 0.005000  loss: 0.1779 (0.2938)  loss_classifier: 0.0801 (0.1386)  loss_box_reg: 0.0873 (0.1269)  loss_objectness: 0.0132 (0.0210)  loss_rpn_box_reg: 0.0035 (0.0073)  time: 1.8800  data: 0.1097  max mem: 6361
# Epoch: [0]  [1340/1596]  eta: 0:07:56  lr: 0.005000  loss: 0.1779 (0.2929)  loss_classifier: 0.0782 (0.1381)  loss_box_reg: 0.0875 (0.1266)  loss_objectness: 0.0083 (0.0210)  loss_rpn_box_reg: 0.0031 (0.0072)  time: 1.8763  data: 0.1130  max mem: 6361
# Epoch: [0]  [1350/1596]  eta: 0:07:38  lr: 0.005000  loss: 0.1881 (0.2923)  loss_classifier: 0.0782 (0.1377)  loss_box_reg: 0.0873 (0.1264)  loss_objectness: 0.0090 (0.0209)  loss_rpn_box_reg: 0.0031 (0.0072)  time: 1.8620  data: 0.1115  max mem: 6361
# Epoch: [0]  [1360/1596]  eta: 0:07:19  lr: 0.005000  loss: 0.1631 (0.2914)  loss_classifier: 0.0716 (0.1372)  loss_box_reg: 0.0816 (0.1261)  loss_objectness: 0.0090 (0.0208)  loss_rpn_box_reg: 0.0030 (0.0072)  time: 1.8395  data: 0.1010  max mem: 6361
# Epoch: [0]  [1370/1596]  eta: 0:07:00  lr: 0.005000  loss: 0.1533 (0.2906)  loss_classifier: 0.0690 (0.1368)  loss_box_reg: 0.0725 (0.1258)  loss_objectness: 0.0065 (0.0207)  loss_rpn_box_reg: 0.0030 (0.0072)  time: 1.8363  data: 0.1006  max mem: 6361
# Epoch: [0]  [1380/1596]  eta: 0:06:42  lr: 0.005000  loss: 0.1666 (0.2901)  loss_classifier: 0.0758 (0.1365)  loss_box_reg: 0.0838 (0.1257)  loss_objectness: 0.0069 (0.0207)  loss_rpn_box_reg: 0.0031 (0.0072)  time: 1.8432  data: 0.1073  max mem: 6361
# Epoch: [0]  [1390/1596]  eta: 0:06:23  lr: 0.005000  loss: 0.1907 (0.2895)  loss_classifier: 0.0821 (0.1361)  loss_box_reg: 0.0887 (0.1255)  loss_objectness: 0.0086 (0.0207)  loss_rpn_box_reg: 0.0033 (0.0072)  time: 1.8516  data: 0.1089  max mem: 6361
# Epoch: [0]  [1400/1596]  eta: 0:06:04  lr: 0.005000  loss: 0.1903 (0.2888)  loss_classifier: 0.0759 (0.1357)  loss_box_reg: 0.0887 (0.1253)  loss_objectness: 0.0084 (0.0206)  loss_rpn_box_reg: 0.0039 (0.0072)  time: 1.8541  data: 0.1054  max mem: 6361
# Epoch: [0]  [1410/1596]  eta: 0:05:46  lr: 0.005000  loss: 0.2107 (0.2884)  loss_classifier: 0.0837 (0.1354)  loss_box_reg: 0.1036 (0.1252)  loss_objectness: 0.0100 (0.0206)  loss_rpn_box_reg: 0.0045 (0.0072)  time: 1.8611  data: 0.1116  max mem: 6361
# Epoch: [0]  [1420/1596]  eta: 0:05:27  lr: 0.005000  loss: 0.2111 (0.2879)  loss_classifier: 0.0966 (0.1351)  loss_box_reg: 0.1036 (0.1250)  loss_objectness: 0.0136 (0.0205)  loss_rpn_box_reg: 0.0050 (0.0072)  time: 1.8545  data: 0.1088  max mem: 6361
# Epoch: [0]  [1430/1596]  eta: 0:05:08  lr: 0.005000  loss: 0.1833 (0.2871)  loss_classifier: 0.0836 (0.1347)  loss_box_reg: 0.0838 (0.1247)  loss_objectness: 0.0094 (0.0205)  loss_rpn_box_reg: 0.0039 (0.0071)  time: 1.8467  data: 0.1068  max mem: 6361
# Epoch: [0]  [1440/1596]  eta: 0:04:50  lr: 0.005000  loss: 0.1568 (0.2863)  loss_classifier: 0.0649 (0.1343)  loss_box_reg: 0.0726 (0.1245)  loss_objectness: 0.0064 (0.0204)  loss_rpn_box_reg: 0.0031 (0.0071)  time: 1.8629  data: 0.1160  max mem: 6361
# Epoch: [0]  [1450/1596]  eta: 0:04:31  lr: 0.005000  loss: 0.1953 (0.2859)  loss_classifier: 0.0764 (0.1339)  loss_box_reg: 0.0917 (0.1243)  loss_objectness: 0.0083 (0.0204)  loss_rpn_box_reg: 0.0040 (0.0071)  time: 1.8738  data: 0.1165  max mem: 6361
# Epoch: [0]  [1460/1596]  eta: 0:04:13  lr: 0.005000  loss: 0.2017 (0.2852)  loss_classifier: 0.0827 (0.1336)  loss_box_reg: 0.0945 (0.1241)  loss_objectness: 0.0119 (0.0204)  loss_rpn_box_reg: 0.0040 (0.0071)  time: 1.8495  data: 0.1074  max mem: 6361
# Epoch: [0]  [1470/1596]  eta: 0:03:54  lr: 0.005000  loss: 0.1628 (0.2845)  loss_classifier: 0.0728 (0.1332)  loss_box_reg: 0.0796 (0.1238)  loss_objectness: 0.0079 (0.0203)  loss_rpn_box_reg: 0.0033 (0.0071)  time: 1.8321  data: 0.1005  max mem: 6361
# Epoch: [0]  [1480/1596]  eta: 0:03:35  lr: 0.005000  loss: 0.1686 (0.2838)  loss_classifier: 0.0712 (0.1328)  loss_box_reg: 0.0832 (0.1236)  loss_objectness: 0.0075 (0.0203)  loss_rpn_box_reg: 0.0028 (0.0071)  time: 1.8681  data: 0.1116  max mem: 6361
# Epoch: [0]  [1490/1596]  eta: 0:03:17  lr: 0.005000  loss: 0.1787 (0.2832)  loss_classifier: 0.0792 (0.1325)  loss_box_reg: 0.0926 (0.1233)  loss_objectness: 0.0096 (0.0203)  loss_rpn_box_reg: 0.0031 (0.0071)  time: 1.8730  data: 0.1126  max mem: 6361
# Epoch: [0]  [1500/1596]  eta: 0:02:58  lr: 0.005000  loss: 0.1604 (0.2825)  loss_classifier: 0.0687 (0.1321)  loss_box_reg: 0.0799 (0.1231)  loss_objectness: 0.0096 (0.0202)  loss_rpn_box_reg: 0.0030 (0.0071)  time: 1.8458  data: 0.1036  max mem: 6361
# Epoch: [0]  [1510/1596]  eta: 0:02:40  lr: 0.005000  loss: 0.1436 (0.2817)  loss_classifier: 0.0583 (0.1316)  loss_box_reg: 0.0770 (0.1228)  loss_objectness: 0.0077 (0.0202)  loss_rpn_box_reg: 0.0027 (0.0071)  time: 1.8564  data: 0.1170  max mem: 6361
# Epoch: [0]  [1520/1596]  eta: 0:02:21  lr: 0.005000  loss: 0.1698 (0.2812)  loss_classifier: 0.0646 (0.1314)  loss_box_reg: 0.0790 (0.1227)  loss_objectness: 0.0077 (0.0201)  loss_rpn_box_reg: 0.0028 (0.0071)  time: 1.8727  data: 0.1197  max mem: 6361
# Epoch: [0]  [1530/1596]  eta: 0:02:02  lr: 0.005000  loss: 0.1785 (0.2805)  loss_classifier: 0.0729 (0.1310)  loss_box_reg: 0.0971 (0.1225)  loss_objectness: 0.0069 (0.0200)  loss_rpn_box_reg: 0.0029 (0.0071)  time: 1.8635  data: 0.1088  max mem: 6361
# Epoch: [0]  [1540/1596]  eta: 0:01:44  lr: 0.005000  loss: 0.1825 (0.2798)  loss_classifier: 0.0711 (0.1306)  loss_box_reg: 0.0933 (0.1222)  loss_objectness: 0.0061 (0.0199)  loss_rpn_box_reg: 0.0029 (0.0071)  time: 1.8487  data: 0.1031  max mem: 6361
# Epoch: [0]  [1550/1596]  eta: 0:01:25  lr: 0.005000  loss: 0.1860 (0.2794)  loss_classifier: 0.0736 (0.1304)  loss_box_reg: 0.0904 (0.1221)  loss_objectness: 0.0096 (0.0199)  loss_rpn_box_reg: 0.0030 (0.0070)  time: 1.8462  data: 0.0990  max mem: 6361
# Epoch: [0]  [1560/1596]  eta: 0:01:07  lr: 0.005000  loss: 0.2036 (0.2790)  loss_classifier: 0.0846 (0.1301)  loss_box_reg: 0.0934 (0.1219)  loss_objectness: 0.0110 (0.0199)  loss_rpn_box_reg: 0.0039 (0.0070)  time: 1.8821  data: 0.1153  max mem: 6361
# Epoch: [0]  [1570/1596]  eta: 0:00:48  lr: 0.005000  loss: 0.1994 (0.2785)  loss_classifier: 0.0850 (0.1299)  loss_box_reg: 0.0999 (0.1218)  loss_objectness: 0.0107 (0.0198)  loss_rpn_box_reg: 0.0038 (0.0070)  time: 1.8878  data: 0.1207  max mem: 6361
# Epoch: [0]  [1580/1596]  eta: 0:00:29  lr: 0.005000  loss: 0.1708 (0.2777)  loss_classifier: 0.0673 (0.1295)  loss_box_reg: 0.0857 (0.1215)  loss_objectness: 0.0086 (0.0198)  loss_rpn_box_reg: 0.0032 (0.0070)  time: 1.9347  data: 0.1351  max mem: 6361
# Epoch: [0]  [1590/1596]  eta: 0:00:11  lr: 0.005000  loss: 0.1495 (0.2772)  loss_classifier: 0.0671 (0.1292)  loss_box_reg: 0.0758 (0.1213)  loss_objectness: 0.0071 (0.0197)  loss_rpn_box_reg: 0.0030 (0.0070)  time: 1.9168  data: 0.1311  max mem: 6361
# Epoch: [0]  [1595/1596]  eta: 0:00:01  lr: 0.005000  loss: 0.1650 (0.2768)  loss_classifier: 0.0693 (0.1290)  loss_box_reg: 0.0773 (0.1211)  loss_objectness: 0.0071 (0.0197)  loss_rpn_box_reg: 0.0027 (0.0070)  time: 1.8144  data: 0.1082  max mem: 6361
# Epoch: [0] Total time: 0:49:31 (1.8617 s / it)
# Test:  [  0/789]  eta: 0:06:22  model_time: 0.1262 (0.1262)  evaluator_time: 0.0192 (0.0192)  time: 0.4852  data: 0.3360  max mem: 6361
# Test:  [100/789]  eta: 0:00:37  model_time: 0.0392 (0.0408)  evaluator_time: 0.0020 (0.0022)  time: 0.0495  data: 0.0049  max mem: 6361
# Test:  [200/789]  eta: 0:00:31  model_time: 0.0403 (0.0408)  evaluator_time: 0.0022 (0.0023)  time: 0.0523  data: 0.0056  max mem: 6361
# Test:  [300/789]  eta: 0:00:26  model_time: 0.0401 (0.0407)  evaluator_time: 0.0018 (0.0023)  time: 0.0532  data: 0.0059  max mem: 6361
# Test:  [400/789]  eta: 0:00:20  model_time: 0.0395 (0.0406)  evaluator_time: 0.0016 (0.0023)  time: 0.0515  data: 0.0051  max mem: 6361
# Test:  [500/789]  eta: 0:00:15  model_time: 0.0387 (0.0406)  evaluator_time: 0.0021 (0.0022)  time: 0.0516  data: 0.0051  max mem: 6361
# Test:  [600/789]  eta: 0:00:09  model_time: 0.0408 (0.0407)  evaluator_time: 0.0017 (0.0022)  time: 0.0521  data: 0.0050  max mem: 6361
# Test:  [700/789]  eta: 0:00:04  model_time: 0.0400 (0.0407)  evaluator_time: 0.0021 (0.0022)  time: 0.0513  data: 0.0051  max mem: 6361
# Test:  [788/789]  eta: 0:00:00  model_time: 0.0402 (0.0407)  evaluator_time: 0.0017 (0.0022)  time: 0.0500  data: 0.0049  max mem: 6361
# Test: Total time: 0:00:41 (0.0525 s / it)
# Averaged stats: model_time: 0.0402 (0.0407)  evaluator_time: 0.0017 (0.0022)
# Accumulating evaluation results...
# DONE (t=0.23s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.526
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.803
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.610
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.108
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.243
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.549
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.513
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.654
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.656
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.133
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.332
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.679
# Epoch: [1]  [   0/1596]  eta: 3:40:08  lr: 0.005000  loss: 0.2850 (0.2850)  loss_classifier: 0.0708 (0.0708)  loss_box_reg: 0.0991 (0.0991)  loss_objectness: 0.0972 (0.0972)  loss_rpn_box_reg: 0.0180 (0.0180)  time: 8.2762  data: 6.3105  max mem: 6361
# Epoch: [1]  [  10/1596]  eta: 1:09:50  lr: 0.005000  loss: 0.1697 (0.1829)  loss_classifier: 0.0687 (0.0699)  loss_box_reg: 0.0856 (0.0869)  loss_objectness: 0.0073 (0.0185)  loss_rpn_box_reg: 0.0039 (0.0076)  time: 2.6423  data: 0.7240  max mem: 6361
# Epoch: [1]  [  20/1596]  eta: 1:00:31  lr: 0.005000  loss: 0.1664 (0.1895)  loss_classifier: 0.0687 (0.0757)  loss_box_reg: 0.0810 (0.0921)  loss_objectness: 0.0073 (0.0150)  loss_rpn_box_reg: 0.0035 (0.0065)  time: 2.0059  data: 0.1343  max mem: 6361
# Epoch: [1]  [  30/1596]  eta: 0:56:19  lr: 0.005000  loss: 0.1765 (0.1869)  loss_classifier: 0.0791 (0.0756)  loss_box_reg: 0.0784 (0.0918)  loss_objectness: 0.0082 (0.0136)  loss_rpn_box_reg: 0.0036 (0.0059)  time: 1.8918  data: 0.0982  max mem: 6361
# Epoch: [1]  [  40/1596]  eta: 0:54:05  lr: 0.005000  loss: 0.1863 (0.1928)  loss_classifier: 0.0767 (0.0770)  loss_box_reg: 0.0940 (0.0951)  loss_objectness: 0.0104 (0.0139)  loss_rpn_box_reg: 0.0039 (0.0068)  time: 1.8564  data: 0.0977  max mem: 6361
# Epoch: [1]  [  50/1596]  eta: 0:52:41  lr: 0.005000  loss: 0.1862 (0.1878)  loss_classifier: 0.0728 (0.0759)  loss_box_reg: 0.0934 (0.0919)  loss_objectness: 0.0098 (0.0137)  loss_rpn_box_reg: 0.0037 (0.0064)  time: 1.8696  data: 0.1016  max mem: 6361
# Epoch: [1]  [  60/1596]  eta: 0:51:36  lr: 0.005000  loss: 0.1602 (0.1878)  loss_classifier: 0.0713 (0.0770)  loss_box_reg: 0.0829 (0.0908)  loss_objectness: 0.0073 (0.0135)  loss_rpn_box_reg: 0.0036 (0.0065)  time: 1.8728  data: 0.0981  max mem: 6361
# Epoch: [1]  [  70/1596]  eta: 0:50:36  lr: 0.005000  loss: 0.1635 (0.1871)  loss_classifier: 0.0730 (0.0775)  loss_box_reg: 0.0867 (0.0907)  loss_objectness: 0.0071 (0.0129)  loss_rpn_box_reg: 0.0032 (0.0060)  time: 1.8492  data: 0.0919  max mem: 6361
# Epoch: [1]  [  80/1596]  eta: 0:49:53  lr: 0.005000  loss: 0.1744 (0.1892)  loss_classifier: 0.0729 (0.0788)  loss_box_reg: 0.0893 (0.0917)  loss_objectness: 0.0072 (0.0128)  loss_rpn_box_reg: 0.0031 (0.0059)  time: 1.8490  data: 0.0914  max mem: 6361
# Epoch: [1]  [  90/1596]  eta: 0:49:07  lr: 0.005000  loss: 0.1667 (0.1853)  loss_classifier: 0.0648 (0.0768)  loss_box_reg: 0.0866 (0.0900)  loss_objectness: 0.0078 (0.0125)  loss_rpn_box_reg: 0.0035 (0.0060)  time: 1.8409  data: 0.0902  max mem: 6361
# Epoch: [1]  [ 100/1596]  eta: 0:48:35  lr: 0.005000  loss: 0.1480 (0.1827)  loss_classifier: 0.0591 (0.0762)  loss_box_reg: 0.0740 (0.0886)  loss_objectness: 0.0073 (0.0121)  loss_rpn_box_reg: 0.0030 (0.0057)  time: 1.8428  data: 0.0936  max mem: 6361
# Epoch: [1]  [ 110/1596]  eta: 0:48:00  lr: 0.005000  loss: 0.1513 (0.1799)  loss_classifier: 0.0622 (0.0750)  loss_box_reg: 0.0725 (0.0875)  loss_objectness: 0.0050 (0.0117)  loss_rpn_box_reg: 0.0026 (0.0056)  time: 1.8516  data: 0.0922  max mem: 6361
# Epoch: [1]  [ 120/1596]  eta: 0:47:34  lr: 0.005000  loss: 0.1437 (0.1795)  loss_classifier: 0.0597 (0.0743)  loss_box_reg: 0.0725 (0.0878)  loss_objectness: 0.0050 (0.0117)  loss_rpn_box_reg: 0.0029 (0.0057)  time: 1.8585  data: 0.0911  max mem: 6361
# Epoch: [1]  [ 130/1596]  eta: 0:47:06  lr: 0.005000  loss: 0.1539 (0.1804)  loss_classifier: 0.0659 (0.0747)  loss_box_reg: 0.0814 (0.0883)  loss_objectness: 0.0073 (0.0117)  loss_rpn_box_reg: 0.0032 (0.0057)  time: 1.8721  data: 0.0929  max mem: 6361
# Epoch: [1]  [ 140/1596]  eta: 0:46:42  lr: 0.005000  loss: 0.1716 (0.1796)  loss_classifier: 0.0679 (0.0742)  loss_box_reg: 0.0855 (0.0878)  loss_objectness: 0.0080 (0.0118)  loss_rpn_box_reg: 0.0031 (0.0058)  time: 1.8692  data: 0.0956  max mem: 6361
# Epoch: [1]  [ 150/1596]  eta: 0:46:18  lr: 0.005000  loss: 0.1462 (0.1782)  loss_classifier: 0.0653 (0.0738)  loss_box_reg: 0.0708 (0.0870)  loss_objectness: 0.0065 (0.0118)  loss_rpn_box_reg: 0.0024 (0.0056)  time: 1.8791  data: 0.0995  max mem: 6361
# Epoch: [1]  [ 160/1596]  eta: 0:45:56  lr: 0.005000  loss: 0.1561 (0.1784)  loss_classifier: 0.0575 (0.0735)  loss_box_reg: 0.0721 (0.0871)  loss_objectness: 0.0098 (0.0121)  loss_rpn_box_reg: 0.0029 (0.0056)  time: 1.8841  data: 0.0931  max mem: 6361
# Epoch: [1]  [ 170/1596]  eta: 0:45:40  lr: 0.005000  loss: 0.1670 (0.1778)  loss_classifier: 0.0631 (0.0734)  loss_box_reg: 0.0887 (0.0869)  loss_objectness: 0.0083 (0.0120)  loss_rpn_box_reg: 0.0028 (0.0055)  time: 1.9245  data: 0.1106  max mem: 6361
# ...
# Epoch: [2]  [ 870/1596]  eta: 0:22:41  lr: 0.005000  loss: 0.1440 (0.1659)  loss_classifier: 0.0564 (0.0668)  loss_box_reg: 0.0731 (0.0834)  loss_objectness: 0.0071 (0.0102)  loss_rpn_box_reg: 0.0027 (0.0055)  time: 1.8649  data: 0.1224  max mem: 6378
# Epoch: [2]  [ 880/1596]  eta: 0:22:23  lr: 0.005000  loss: 0.1478 (0.1660)  loss_classifier: 0.0621 (0.0668)  loss_box_reg: 0.0748 (0.0834)  loss_objectness: 0.0080 (0.0102)  loss_rpn_box_reg: 0.0032 (0.0056)  time: 1.8725  data: 0.1180  max mem: 6378
# Epoch: [2]  [ 890/1596]  eta: 0:22:04  lr: 0.005000  loss: 0.1720 (0.1663)  loss_classifier: 0.0661 (0.0669)  loss_box_reg: 0.0821 (0.0836)  loss_objectness: 0.0074 (0.0102)  loss_rpn_box_reg: 0.0037 (0.0056)  time: 1.8954  data: 0.1303  max mem: 6378
# Epoch: [2]  [ 900/1596]  eta: 0:21:45  lr: 0.005000  loss: 0.1783 (0.1663)  loss_classifier: 0.0742 (0.0669)  loss_box_reg: 0.0828 (0.0836)  loss_objectness: 0.0066 (0.0102)  loss_rpn_box_reg: 0.0033 (0.0056)  time: 1.8684  data: 0.1222  max mem: 6378
# Epoch: [2]  [ 910/1596]  eta: 0:21:26  lr: 0.005000  loss: 0.1783 (0.1666)  loss_classifier: 0.0723 (0.0670)  loss_box_reg: 0.0828 (0.0837)  loss_objectness: 0.0082 (0.0102)  loss_rpn_box_reg: 0.0032 (0.0056)  time: 1.8488  data: 0.1024  max mem: 6378
# Epoch: [2]  [ 920/1596]  eta: 0:21:07  lr: 0.005000  loss: 0.1714 (0.1664)  loss_classifier: 0.0620 (0.0670)  loss_box_reg: 0.0753 (0.0836)  loss_objectness: 0.0072 (0.0102)  loss_rpn_box_reg: 0.0031 (0.0056)  time: 1.8723  data: 0.1152  max mem: 6378
# Epoch: [2]  [ 930/1596]  eta: 0:20:48  lr: 0.005000  loss: 0.1391 (0.1662)  loss_classifier: 0.0610 (0.0669)  loss_box_reg: 0.0675 (0.0835)  loss_objectness: 0.0072 (0.0102)  loss_rpn_box_reg: 0.0027 (0.0056)  time: 1.8639  data: 0.1121  max mem: 6378
# Epoch: [2]  [ 940/1596]  eta: 0:20:31  lr: 0.005000  loss: 0.1545 (0.1663)  loss_classifier: 0.0599 (0.0669)  loss_box_reg: 0.0758 (0.0836)  loss_objectness: 0.0073 (0.0102)  loss_rpn_box_reg: 0.0027 (0.0056)  time: 1.9370  data: 0.1506  max mem: 6378
# Epoch: [2]  [ 950/1596]  eta: 0:20:12  lr: 0.005000  loss: 0.1682 (0.1663)  loss_classifier: 0.0624 (0.0670)  loss_box_reg: 0.0831 (0.0835)  loss_objectness: 0.0102 (0.0102)  loss_rpn_box_reg: 0.0037 (0.0056)  time: 1.9849  data: 0.1760  max mem: 6378
# Epoch: [2]  [ 960/1596]  eta: 0:19:54  lr: 0.005000  loss: 0.1367 (0.1663)  loss_classifier: 0.0530 (0.0669)  loss_box_reg: 0.0678 (0.0835)  loss_objectness: 0.0099 (0.0103)  loss_rpn_box_reg: 0.0030 (0.0056)  time: 1.9196  data: 0.1439  max mem: 6378
# Epoch: [2]  [ 970/1596]  eta: 0:19:35  lr: 0.005000  loss: 0.1679 (0.1666)  loss_classifier: 0.0633 (0.0670)  loss_box_reg: 0.0783 (0.0836)  loss_objectness: 0.0101 (0.0103)  loss_rpn_box_reg: 0.0038 (0.0057)  time: 1.8841  data: 0.1306  max mem: 6378
# Epoch: [2]  [ 980/1596]  eta: 0:19:16  lr: 0.005000  loss: 0.1625 (0.1665)  loss_classifier: 0.0678 (0.0670)  loss_box_reg: 0.0792 (0.0835)  loss_objectness: 0.0090 (0.0103)  loss_rpn_box_reg: 0.0034 (0.0057)  time: 1.8888  data: 0.1269  max mem: 6378
# Epoch: [2]  [ 990/1596]  eta: 0:18:58  lr: 0.005000  loss: 0.1514 (0.1663)  loss_classifier: 0.0606 (0.0669)  loss_box_reg: 0.0728 (0.0835)  loss_objectness: 0.0062 (0.0103)  loss_rpn_box_reg: 0.0028 (0.0056)  time: 1.8932  data: 0.1245  max mem: 6378
# Epoch: [2]  [1000/1596]  eta: 0:18:39  lr: 0.005000  loss: 0.1539 (0.1663)  loss_classifier: 0.0606 (0.0669)  loss_box_reg: 0.0814 (0.0835)  loss_objectness: 0.0069 (0.0103)  loss_rpn_box_reg: 0.0024 (0.0056)  time: 1.8836  data: 0.1199  max mem: 6378
# Epoch: [2]  [1010/1596]  eta: 0:18:20  lr: 0.005000  loss: 0.1390 (0.1660)  loss_classifier: 0.0582 (0.0668)  loss_box_reg: 0.0734 (0.0833)  loss_objectness: 0.0053 (0.0102)  loss_rpn_box_reg: 0.0030 (0.0056)  time: 1.8851  data: 0.1189  max mem: 6378
# Epoch: [2]  [1020/1596]  eta: 0:18:02  lr: 0.005000  loss: 0.1430 (0.1660)  loss_classifier: 0.0582 (0.0668)  loss_box_reg: 0.0707 (0.0834)  loss_objectness: 0.0045 (0.0102)  loss_rpn_box_reg: 0.0032 (0.0056)  time: 1.9049  data: 0.1249  max mem: 6378
# Epoch: [2]  [1030/1596]  eta: 0:17:43  lr: 0.005000  loss: 0.1500 (0.1660)  loss_classifier: 0.0620 (0.0668)  loss_box_reg: 0.0786 (0.0833)  loss_objectness: 0.0064 (0.0102)  loss_rpn_box_reg: 0.0032 (0.0056)  time: 1.9488  data: 0.1398  max mem: 6378
# Epoch: [2]  [1040/1596]  eta: 0:17:25  lr: 0.005000  loss: 0.1491 (0.1659)  loss_classifier: 0.0615 (0.0668)  loss_box_reg: 0.0779 (0.0833)  loss_objectness: 0.0080 (0.0102)  loss_rpn_box_reg: 0.0032 (0.0056)  time: 1.9545  data: 0.1384  max mem: 6378
# Epoch: [2]  [1050/1596]  eta: 0:17:06  lr: 0.005000  loss: 0.1553 (0.1659)  loss_classifier: 0.0617 (0.0668)  loss_box_reg: 0.0759 (0.0832)  loss_objectness: 0.0068 (0.0102)  loss_rpn_box_reg: 0.0028 (0.0056)  time: 1.9437  data: 0.1264  max mem: 6378
# Epoch: [2]  [1060/1596]  eta: 0:16:48  lr: 0.005000  loss: 0.1466 (0.1657)  loss_classifier: 0.0563 (0.0668)  loss_box_reg: 0.0759 (0.0832)  loss_objectness: 0.0059 (0.0102)  loss_rpn_box_reg: 0.0025 (0.0056)  time: 1.9163  data: 0.1222  max mem: 6378
# Epoch: [2]  [1070/1596]  eta: 0:16:29  lr: 0.005000  loss: 0.1417 (0.1657)  loss_classifier: 0.0563 (0.0667)  loss_box_reg: 0.0721 (0.0831)  loss_objectness: 0.0057 (0.0102)  loss_rpn_box_reg: 0.0027 (0.0056)  time: 1.9176  data: 0.1253  max mem: 6378
# Epoch: [2]  [1080/1596]  eta: 0:16:11  lr: 0.005000  loss: 0.1379 (0.1656)  loss_classifier: 0.0565 (0.0667)  loss_box_reg: 0.0707 (0.0831)  loss_objectness: 0.0059 (0.0102)  loss_rpn_box_reg: 0.0029 (0.0056)  time: 1.9412  data: 0.1243  max mem: 6378
# Epoch: [2]  [1090/1596]  eta: 0:15:52  lr: 0.005000  loss: 0.1330 (0.1654)  loss_classifier: 0.0564 (0.0666)  loss_box_reg: 0.0707 (0.0831)  loss_objectness: 0.0049 (0.0102)  loss_rpn_box_reg: 0.0028 (0.0056)  time: 1.9124  data: 0.1151  max mem: 6378
# Epoch: [2]  [1100/1596]  eta: 0:15:33  lr: 0.005000  loss: 0.1306 (0.1652)  loss_classifier: 0.0524 (0.0665)  loss_box_reg: 0.0686 (0.0830)  loss_objectness: 0.0058 (0.0102)  loss_rpn_box_reg: 0.0026 (0.0056)  time: 1.8951  data: 0.1193  max mem: 6378
# Epoch: [2]  [1110/1596]  eta: 0:15:14  lr: 0.005000  loss: 0.1317 (0.1653)  loss_classifier: 0.0509 (0.0664)  loss_box_reg: 0.0730 (0.0829)  loss_objectness: 0.0065 (0.0102)  loss_rpn_box_reg: 0.0026 (0.0058)  time: 1.9132  data: 0.1247  max mem: 6378
# Epoch: [2]  [1120/1596]  eta: 0:14:56  lr: 0.005000  loss: 0.1623 (0.1654)  loss_classifier: 0.0555 (0.0664)  loss_box_reg: 0.0825 (0.0830)  loss_objectness: 0.0078 (0.0102)  loss_rpn_box_reg: 0.0030 (0.0058)  time: 1.9154  data: 0.1213  max mem: 6378
# Epoch: [2]  [1130/1596]  eta: 0:14:37  lr: 0.005000  loss: 0.1596 (0.1654)  loss_classifier: 0.0582 (0.0663)  loss_box_reg: 0.0863 (0.0830)  loss_objectness: 0.0079 (0.0102)  loss_rpn_box_reg: 0.0031 (0.0058)  time: 1.9527  data: 0.1326  max mem: 6378
# Epoch: [2]  [1140/1596]  eta: 0:14:19  lr: 0.005000  loss: 0.1583 (0.1655)  loss_classifier: 0.0630 (0.0664)  loss_box_reg: 0.0843 (0.0831)  loss_objectness: 0.0099 (0.0103)  loss_rpn_box_reg: 0.0033 (0.0058)  time: 1.9776  data: 0.1452  max mem: 6378
# Epoch: [2]  [1150/1596]  eta: 0:14:00  lr: 0.005000  loss: 0.1647 (0.1655)  loss_classifier: 0.0630 (0.0664)  loss_box_reg: 0.0792 (0.0831)  loss_objectness: 0.0089 (0.0103)  loss_rpn_box_reg: 0.0030 (0.0058)  time: 1.9748  data: 0.1455  max mem: 6378
# Epoch: [2]  [1160/1596]  eta: 0:13:42  lr: 0.005000  loss: 0.1701 (0.1656)  loss_classifier: 0.0681 (0.0664)  loss_box_reg: 0.0871 (0.0831)  loss_objectness: 0.0086 (0.0103)  loss_rpn_box_reg: 0.0031 (0.0058)  time: 1.9725  data: 0.1410  max mem: 6378
# Epoch: [2]  [1170/1596]  eta: 0:13:23  lr: 0.005000  loss: 0.1602 (0.1655)  loss_classifier: 0.0648 (0.0664)  loss_box_reg: 0.0871 (0.0831)  loss_objectness: 0.0075 (0.0103)  loss_rpn_box_reg: 0.0033 (0.0057)  time: 1.9233  data: 0.1252  max mem: 6378
# Epoch: [2]  [1180/1596]  eta: 0:13:04  lr: 0.005000  loss: 0.1602 (0.1655)  loss_classifier: 0.0648 (0.0664)  loss_box_reg: 0.0799 (0.0831)  loss_objectness: 0.0057 (0.0103)  loss_rpn_box_reg: 0.0036 (0.0058)  time: 1.8840  data: 0.1170  max mem: 6378
# Epoch: [2]  [1190/1596]  eta: 0:12:46  lr: 0.005000  loss: 0.1612 (0.1657)  loss_classifier: 0.0673 (0.0665)  loss_box_reg: 0.0802 (0.0831)  loss_objectness: 0.0082 (0.0103)  loss_rpn_box_reg: 0.0043 (0.0058)  time: 1.9822  data: 0.1760  max mem: 6378
# Epoch: [2]  [1200/1596]  eta: 0:12:27  lr: 0.005000  loss: 0.1600 (0.1658)  loss_classifier: 0.0668 (0.0665)  loss_box_reg: 0.0788 (0.0832)  loss_objectness: 0.0097 (0.0103)  loss_rpn_box_reg: 0.0041 (0.0057)  time: 2.0475  data: 0.2044  max mem: 6378
# Epoch: [2]  [1210/1596]  eta: 0:12:09  lr: 0.005000  loss: 0.1600 (0.1658)  loss_classifier: 0.0658 (0.0665)  loss_box_reg: 0.0791 (0.0832)  loss_objectness: 0.0086 (0.0103)  loss_rpn_box_reg: 0.0031 (0.0057)  time: 1.9754  data: 0.1570  max mem: 6378
# Epoch: [2]  [1220/1596]  eta: 0:11:50  lr: 0.005000  loss: 0.1614 (0.1658)  loss_classifier: 0.0614 (0.0665)  loss_box_reg: 0.0799 (0.0832)  loss_objectness: 0.0078 (0.0103)  loss_rpn_box_reg: 0.0029 (0.0057)  time: 1.9391  data: 0.1341  max mem: 6378
# Epoch: [2]  [1230/1596]  eta: 0:11:31  lr: 0.005000  loss: 0.1562 (0.1659)  loss_classifier: 0.0614 (0.0666)  loss_box_reg: 0.0784 (0.0832)  loss_objectness: 0.0061 (0.0103)  loss_rpn_box_reg: 0.0026 (0.0057)  time: 1.9006  data: 0.1203  max mem: 6378
# Epoch: [2]  [1240/1596]  eta: 0:11:12  lr: 0.005000  loss: 0.1700 (0.1660)  loss_classifier: 0.0663 (0.0666)  loss_box_reg: 0.0882 (0.0833)  loss_objectness: 0.0059 (0.0103)  loss_rpn_box_reg: 0.0034 (0.0058)  time: 1.9049  data: 0.1212  max mem: 6378
# Epoch: [2]  [1250/1596]  eta: 0:10:53  lr: 0.005000  loss: 0.1841 (0.1661)  loss_classifier: 0.0663 (0.0667)  loss_box_reg: 0.0890 (0.0833)  loss_objectness: 0.0073 (0.0103)  loss_rpn_box_reg: 0.0034 (0.0058)  time: 1.9265  data: 0.1230  max mem: 6378
# Epoch: [2]  [1260/1596]  eta: 0:10:35  lr: 0.005000  loss: 0.1649 (0.1661)  loss_classifier: 0.0618 (0.0667)  loss_box_reg: 0.0864 (0.0833)  loss_objectness: 0.0084 (0.0103)  loss_rpn_box_reg: 0.0033 (0.0058)  time: 1.9435  data: 0.1233  max mem: 6378
# Epoch: [2]  [1270/1596]  eta: 0:10:16  lr: 0.005000  loss: 0.1604 (0.1661)  loss_classifier: 0.0594 (0.0666)  loss_box_reg: 0.0790 (0.0834)  loss_objectness: 0.0094 (0.0103)  loss_rpn_box_reg: 0.0042 (0.0058)  time: 1.9451  data: 0.1444  max mem: 6378
# Epoch: [2]  [1280/1596]  eta: 0:09:57  lr: 0.005000  loss: 0.1847 (0.1662)  loss_classifier: 0.0687 (0.0666)  loss_box_reg: 0.0817 (0.0834)  loss_objectness: 0.0074 (0.0104)  loss_rpn_box_reg: 0.0043 (0.0059)  time: 1.9656  data: 0.1585  max mem: 6378
# Epoch: [2]  [1290/1596]  eta: 0:09:39  lr: 0.005000  loss: 0.1861 (0.1665)  loss_classifier: 0.0701 (0.0667)  loss_box_reg: 0.0914 (0.0836)  loss_objectness: 0.0074 (0.0103)  loss_rpn_box_reg: 0.0038 (0.0059)  time: 2.0176  data: 0.1829  max mem: 6378
# Epoch: [2]  [1300/1596]  eta: 0:09:20  lr: 0.005000  loss: 0.1745 (0.1666)  loss_classifier: 0.0701 (0.0667)  loss_box_reg: 0.0899 (0.0836)  loss_objectness: 0.0071 (0.0103)  loss_rpn_box_reg: 0.0042 (0.0059)  time: 1.9812  data: 0.1702  max mem: 6378
# Epoch: [2]  [1310/1596]  eta: 0:09:01  lr: 0.005000  loss: 0.1664 (0.1670)  loss_classifier: 0.0743 (0.0669)  loss_box_reg: 0.0895 (0.0838)  loss_objectness: 0.0078 (0.0104)  loss_rpn_box_reg: 0.0042 (0.0059)  time: 1.9196  data: 0.1288  max mem: 6378
# Epoch: [2]  [1320/1596]  eta: 0:08:42  lr: 0.005000  loss: 0.1975 (0.1673)  loss_classifier: 0.0765 (0.0670)  loss_box_reg: 0.1000 (0.0839)  loss_objectness: 0.0111 (0.0104)  loss_rpn_box_reg: 0.0042 (0.0059)  time: 1.9323  data: 0.1228  max mem: 6378
# Epoch: [2]  [1330/1596]  eta: 0:08:23  lr: 0.005000  loss: 0.1904 (0.1673)  loss_classifier: 0.0750 (0.0670)  loss_box_reg: 0.0932 (0.0839)  loss_objectness: 0.0111 (0.0105)  loss_rpn_box_reg: 0.0042 (0.0059)  time: 1.9523  data: 0.1306  max mem: 6378
# Epoch: [2]  [1340/1596]  eta: 0:08:04  lr: 0.005000  loss: 0.1562 (0.1673)  loss_classifier: 0.0580 (0.0669)  loss_box_reg: 0.0816 (0.0839)  loss_objectness: 0.0099 (0.0105)  loss_rpn_box_reg: 0.0031 (0.0059)  time: 1.8993  data: 0.1311  max mem: 6378
# Epoch: [2]  [1350/1596]  eta: 0:07:45  lr: 0.005000  loss: 0.1471 (0.1672)  loss_classifier: 0.0573 (0.0669)  loss_box_reg: 0.0741 (0.0839)  loss_objectness: 0.0062 (0.0105)  loss_rpn_box_reg: 0.0030 (0.0059)  time: 1.8609  data: 0.1186  max mem: 6378
# Epoch: [2]  [1360/1596]  eta: 0:07:26  lr: 0.005000  loss: 0.1471 (0.1673)  loss_classifier: 0.0599 (0.0669)  loss_box_reg: 0.0741 (0.0839)  loss_objectness: 0.0083 (0.0105)  loss_rpn_box_reg: 0.0034 (0.0059)  time: 1.8782  data: 0.1203  max mem: 6378
# Epoch: [2]  [1370/1596]  eta: 0:07:07  lr: 0.005000  loss: 0.1574 (0.1672)  loss_classifier: 0.0615 (0.0668)  loss_box_reg: 0.0800 (0.0839)  loss_objectness: 0.0084 (0.0105)  loss_rpn_box_reg: 0.0035 (0.0060)  time: 1.8867  data: 0.1230  max mem: 6378
# Epoch: [2]  [1380/1596]  eta: 0:06:48  lr: 0.005000  loss: 0.1524 (0.1670)  loss_classifier: 0.0615 (0.0667)  loss_box_reg: 0.0732 (0.0838)  loss_objectness: 0.0055 (0.0105)  loss_rpn_box_reg: 0.0034 (0.0059)  time: 1.8816  data: 0.1259  max mem: 6378
# Epoch: [2]  [1390/1596]  eta: 0:06:29  lr: 0.005000  loss: 0.1521 (0.1670)  loss_classifier: 0.0597 (0.0667)  loss_box_reg: 0.0716 (0.0838)  loss_objectness: 0.0047 (0.0105)  loss_rpn_box_reg: 0.0031 (0.0060)  time: 1.8749  data: 0.1263  max mem: 6378
# Epoch: [2]  [1400/1596]  eta: 0:06:11  lr: 0.005000  loss: 0.1580 (0.1670)  loss_classifier: 0.0620 (0.0668)  loss_box_reg: 0.0773 (0.0838)  loss_objectness: 0.0066 (0.0105)  loss_rpn_box_reg: 0.0027 (0.0060)  time: 1.8832  data: 0.1183  max mem: 6378
# Epoch: [2]  [1410/1596]  eta: 0:05:52  lr: 0.005000  loss: 0.1659 (0.1671)  loss_classifier: 0.0683 (0.0668)  loss_box_reg: 0.0871 (0.0838)  loss_objectness: 0.0063 (0.0105)  loss_rpn_box_reg: 0.0027 (0.0060)  time: 1.8907  data: 0.1127  max mem: 6378
# Epoch: [2]  [1420/1596]  eta: 0:05:33  lr: 0.005000  loss: 0.1501 (0.1670)  loss_classifier: 0.0575 (0.0667)  loss_box_reg: 0.0800 (0.0838)  loss_objectness: 0.0061 (0.0105)  loss_rpn_box_reg: 0.0027 (0.0059)  time: 1.8759  data: 0.1111  max mem: 6378
# Epoch: [2]  [1430/1596]  eta: 0:05:14  lr: 0.005000  loss: 0.1521 (0.1671)  loss_classifier: 0.0575 (0.0668)  loss_box_reg: 0.0800 (0.0838)  loss_objectness: 0.0076 (0.0105)  loss_rpn_box_reg: 0.0029 (0.0059)  time: 1.8649  data: 0.1050  max mem: 6378
# Epoch: [2]  [1440/1596]  eta: 0:04:55  lr: 0.005000  loss: 0.1443 (0.1668)  loss_classifier: 0.0561 (0.0667)  loss_box_reg: 0.0699 (0.0837)  loss_objectness: 0.0054 (0.0105)  loss_rpn_box_reg: 0.0029 (0.0059)  time: 1.8463  data: 0.0960  max mem: 6378
# Epoch: [2]  [1450/1596]  eta: 0:04:36  lr: 0.005000  loss: 0.1375 (0.1668)  loss_classifier: 0.0520 (0.0666)  loss_box_reg: 0.0690 (0.0837)  loss_objectness: 0.0051 (0.0105)  loss_rpn_box_reg: 0.0024 (0.0059)  time: 1.8320  data: 0.0972  max mem: 6378
# Epoch: [2]  [1460/1596]  eta: 0:04:17  lr: 0.005000  loss: 0.1466 (0.1667)  loss_classifier: 0.0614 (0.0666)  loss_box_reg: 0.0760 (0.0837)  loss_objectness: 0.0056 (0.0105)  loss_rpn_box_reg: 0.0027 (0.0059)  time: 1.8471  data: 0.1064  max mem: 6378
# Epoch: [2]  [1470/1596]  eta: 0:03:58  lr: 0.005000  loss: 0.1342 (0.1665)  loss_classifier: 0.0574 (0.0665)  loss_box_reg: 0.0699 (0.0836)  loss_objectness: 0.0063 (0.0105)  loss_rpn_box_reg: 0.0028 (0.0059)  time: 1.8699  data: 0.1170  max mem: 6378
# Epoch: [2]  [1480/1596]  eta: 0:03:39  lr: 0.005000  loss: 0.1342 (0.1664)  loss_classifier: 0.0572 (0.0665)  loss_box_reg: 0.0691 (0.0835)  loss_objectness: 0.0066 (0.0105)  loss_rpn_box_reg: 0.0035 (0.0059)  time: 1.8650  data: 0.1184  max mem: 6378
# Epoch: [2]  [1490/1596]  eta: 0:03:20  lr: 0.005000  loss: 0.1369 (0.1664)  loss_classifier: 0.0572 (0.0665)  loss_box_reg: 0.0691 (0.0835)  loss_objectness: 0.0085 (0.0105)  loss_rpn_box_reg: 0.0034 (0.0059)  time: 1.8265  data: 0.1083  max mem: 6378

# %%
plt.plot(loss_graph)

# %%
# save model weights
save_path = f"/content/drive/MyDrive/model.ptf"
torch.save(model.state_dict(), save_path)

# %% [markdown]
# ## Visualization of results
#
# Now that training has finished, let's have a look at what it actually predicts.

# %%
# pick one image from the validation set
img, _ = val_dataset[391]

model.eval()
with torch.no_grad():
    prediction = model([img.to(device)])

prediction

# %% [markdown]
# Printing the prediction shows that we have a list of dictionaries. Each element of the list corresponds to a different image. As we have a single image, there is a single dictionary in the list.
# The dictionary contains the predictions for the image we passed. In this case, we can see that it contains `boxes`, `labels`, and `scores` as fields.
#
# Let's inspect the image and the predicted boxes.
# For that, we need to convert the image, which has been rescaled to 0-1 and had the channels flipped so that we have it in `[C, H, W]` format.

# %%
# convert the image, which has been rescaled to 0-1 and had the channels flipped
pred_img = Image.fromarray(img.mul(255).permute(1, 2, 0).byte().numpy())
draw = ImageDraw.Draw(pred_img)

img_preds = prediction[0]
for i in range(len(img_preds["boxes"])):
    x1, y1, x2, y2 = img_preds["boxes"][i]
    label = int(img_preds["labels"][i])
    score = float(img_preds["scores"][i])

    draw.rectangle(((x1, y1), (x2, y2)), outline="red")
    text = f'{dataset.cat2name[label]}: {score}'
    draw.text((x1+5, y1+5), text)

display(pred_img)

# %% [markdown]
# ## Post-processing
#
# We might notice that there are duplicate detections in the image. Let's post-process the detections with non-maximum suppression.
#
# ** Update: FasterRCNN already has NMS built into it, so you actually do not need to do NMS again.

# %%
img_preds = prediction[0]
keep_idx = batched_nms(boxes=img_preds["boxes"], scores=img_preds["scores"], idxs=img_preds["labels"], iou_threshold=params['IOU_THRESHOLD'])

# %% [markdown]
# Check the predictions again after applying nms.
#
# ** Update: You should not see any difference unless you have specified a lower IoU threshold than the default of 0.5.

# %%
# convert the image, which has been rescaled to 0-1 and had the channels flipped
pred_img = Image.fromarray(img.mul(255).permute(1, 2, 0).byte().numpy())
draw = ImageDraw.Draw(pred_img)

for i in range(len(img_preds["boxes"])):
    if i in keep_idx:
        x1, y1, x2, y2 = img_preds["boxes"][i]
        label = int(img_preds["labels"][i])
        score = float(img_preds["scores"][i])

        draw.rectangle(((x1, y1), (x2, y2)), outline="red")
        text = f'{dataset.cat2name[label]}: {score}'
        draw.text((x1+5, y1+5), text)

display(pred_img)

# %% [markdown]
# Now, let's further filter out the non-confident detections.

# %%
det_threshold = 0.5

# convert the image, which has been rescaled to 0-1 and had the channels flipped
pred_img = Image.fromarray(img.mul(255).permute(1, 2, 0).byte().numpy())
draw = ImageDraw.Draw(pred_img)

for i in range(len(img_preds["boxes"])):
    if i in keep_idx:
        x1, y1, x2, y2 = img_preds["boxes"][i]
        label = int(img_preds["labels"][i])
        score = float(img_preds["scores"][i])

        # filter out non-confident detections
        if score > det_threshold:
            draw.rectangle(((x1, y1), (x2, y2)), outline="red")
            text = f'{dataset.cat2name[label]}: {score}'
            draw.text((x1+5, y1+5), text)

display(pred_img)

# %% [markdown]
# Much better! Once you are satisfied with the results, save your model weights.

# %% [markdown]
# ## Evaluation on Validation Set
#
# As a sanity check, let's evaluate the model performance on the validation set

# %%
with open(val_annotation) as json_file:
    val_data = json.load(json_file)

model.eval()
detections = []
with torch.no_grad():
    for image in val_data["images"]:
        img_name = image["file_name"]
        img_id = image["id"]

        img = Image.open(os.path.join(til_root, 'images', img_name)).convert('RGB')
        img_tensor = transforms.ToTensor()(img)

        preds = model([img_tensor.to(device)])[0]

        for i in range(len(preds["boxes"])):
            x1, y1, x2, y2 = preds["boxes"][i]
            label = int(preds["labels"][i])
            score = float(preds["scores"][i])

            left = int(x1)
            top = int(y1)
            width = int(x2 - x1)
            height = int(y2 - y1)

            detections.append({'image_id':img_id, 'category_id':label, 'bbox':[left, top, width, height], 'score':score})

# %%
validation_json = f"{base_folder}/{params['FILE_NAME']}/val.json"
with open(validation_json, 'w') as f:
    json.dump(detections, f)

# %%
# Get evaluation score against validation set to make sure your prediction json file is in the correct format
coco_gt = COCO(val_annotation)
coco_dt = coco_gt.loadRes(validation_json)
cocoEval = COCOeval(cocoGt=coco_gt, cocoDt=coco_dt, iouType='bbox')
cocoEval.evaluate()
cocoEval.accumulate()
cocoEval.summarize()

# %% [markdown]
# ## Generate Predictions on Test Images

# %%
# You should already have uploaded the testing images onto your google drive.

testing_images_path = os.path.join(base_folder, "c1_test_release.zip") # change this path to the zip file for the test images
# !unzip $testing_images_path

# %%
til_test_root = "/content/c1_test_release/" # extracted testing images path
test_img_root = os.path.join(til_test_root, "images")
img_dir = os.scandir(test_img_root)

# %%
# load model weights (if not using the current trained model)
model.load_state_dict(torch.load(save_path, map_location=device))
model.to(device)
model.eval()

# %% [markdown]
# Let's visualize some predictions on the test images. Run this a few times to visualize different images.

# %%
img = Image.open(next(img_dir).path).convert('RGB')
draw = ImageDraw.Draw(img)
det_threshold = 0.5

# do the prediction
with torch.no_grad():
    img_tensor = transforms.ToTensor()(img)
    img_preds = model([img_tensor.to(device)])[0]

for i in range(len(img_preds["boxes"])):
    x1, y1, x2, y2 = img_preds["boxes"][i]
    label = int(img_preds["labels"][i])
    score = float(img_preds["scores"][i])

    # filter out non-confident detections
    if score > det_threshold:
        draw.rectangle(((x1, y1), (x2, y2)), outline="red")
        text = f'{dataset.cat2name[label]}: {score}'
        draw.text((x1+5, y1+5), text)

display(img)

# %% [markdown]
# ## Submission of Results
#
# Submission json file should be in [COCO format](https://cocodataset.org/#format-results).
#
# ```
# [{
#     "image_id": int,
#     "category_id": int,
#     "bbox": [x,y,width,height],
#     "score": float,
# }]
# ```
#
# Refer to **sample_submission_cv.json** for an example.
#
# For this competition, the metric for evaluation will be mAP @ 0.50:0.95

# %%
# generate detections on the folder of test images (this will be used for submission)
detections = []
with torch.no_grad():
    for image in img_dir:
        img_id = int(image.name.split('.')[0])

        img = Image.open(image.path).convert('RGB')
        img_tensor = transforms.ToTensor()(img)

        preds = model([img_tensor.to(device)])[0]

        for i in range(len(preds["boxes"])):
            x1, y1, x2, y2 = preds["boxes"][i]
            label = int(preds["labels"][i])
            score = float(preds["scores"][i])

            left = int(x1)
            top = int(y1)
            width = int(x2 - x1)
            height = int(y2 - y1)

            detections.append({'image_id':img_id, 'category_id':label, 'bbox':[left, top, width, height], 'score':score})

# %%
test_pred_json = f"{base_folder}/{params['FILE_NAME']}/challenge_1_team_HereToLearn.json"
with open(test_pred_json, 'w') as f:
    json.dump(detections, f)

# %% [markdown]
# ## Check Your Submission JSON Format (RUN THIS BEFORE SUBMISSION)
#
# Run this function first with the given sample json (change this path for the different challenges) to make sure everything works before you submit. Just need to ensure that there are no errors when you run this. **If you get any errors, check your generated json file.**

# %%
sample_json_path = os.path.join(til_test_root, "c1_test_sample.json")

coco_gt = COCO(sample_json_path)
coco_dt = coco_gt.loadRes(test_pred_json)
cocoEval = COCOeval(cocoGt=coco_gt, cocoDt=coco_dt, iouType='bbox')
cocoEval.evaluate()
cocoEval.accumulate()
cocoEval.summarize()

# %% [markdown]
# If you get an `AssertionError: Results do not correspond to current coco set`, it most likely means that some of the "image_id" are out of range (either 0 or higher than number of test images).
